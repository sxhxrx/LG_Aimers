# %% [markdown]
# ### Import

# %%
# !pip install optuna-integration[sklearn]
# Out:
# Collecting optuna-integration[sklearn]
#   Downloading optuna_integration-4.2.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: optuna in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from optuna-integration[sklearn]) (4.2.1)
# Requirement already satisfied: pandas in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from optuna-integration[sklearn]) (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from optuna-integration[sklearn]) (1.6.1)
# Requirement already satisfied: scipy in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from optuna-integration[sklearn]) (1.15.1)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from optuna->optuna-integration[sklearn]) (1.13.3)
# Requirement already satisfied: colorlog in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from optuna->optuna-integration[sklearn]) (6.9.0)
# Requirement already satisfied: numpy in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from optuna->optuna-integration[sklearn]) (2.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from optuna->optuna-integration[sklearn]) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from optuna->optuna-integration[sklearn]) (2.0.37)
# Requirement already satisfied: tqdm in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from optuna->optuna-integration[sklearn]) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from optuna->optuna-integration[sklearn]) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from pandas->optuna-integration[sklearn]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from pandas->optuna-integration[sklearn]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from pandas->optuna-integration[sklearn]) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from scikit-learn->optuna-integration[sklearn]) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from scikit-learn->optuna-integration[sklearn]) (3.5.0)
# Requirement already satisfied: Mako in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from alembic>=1.5.0->optuna->optuna-integration[sklearn]) (1.2.3)
# Requirement already satisfied: typing-extensions>=4 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from alembic>=1.5.0->optuna->optuna-integration[sklearn]) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from python-dateutil>=2.8.2->pandas->optuna-integration[sklearn]) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from sqlalchemy>=1.4.2->optuna->optuna-integration[sklearn]) (3.1.1)
# Requirement already satisfied: colorama in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from colorlog->optuna->optuna-integration[sklearn]) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from Mako->alembic>=1.5.0->optuna->optuna-integration[sklearn]) (3.0.2)
# Downloading optuna_integration-4.2.1-py3-none-any.whl (97 kB)
# Installing collected packages: optuna-integration
# Successfully installed optuna-integration-4.2.1

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import  OrdinalEncoder

import optuna
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from optuna.integration import OptunaSearchCV

# %% [markdown]
# ### Data Load

# %%
train = pd.read_csv('./Data/train.csv').drop(columns=['ID'])
test = pd.read_csv('./Data/test.csv').drop(columns=['ID'])

# %%
X = train.drop('임신 성공 여부', axis=1)
y = train['임신 성공 여부']

# %% [markdown]
# ### Data Pre-processing

# %%
categorical_columns = [
    "시술 시기 코드",
    "시술 당시 나이",
    "시술 유형",
    "특정 시술 유형",
    "배란 자극 여부",
    "배란 유도 유형",
    "단일 배아 이식 여부",
    "착상 전 유전 검사 사용 여부",
    "착상 전 유전 진단 사용 여부",
    "남성 주 불임 원인",
    "남성 부 불임 원인",
    "여성 주 불임 원인",
    "여성 부 불임 원인",
    "부부 주 불임 원인",
    "부부 부 불임 원인",
    "불명확 불임 원인",
    "불임 원인 - 난관 질환",
    "불임 원인 - 남성 요인",
    "불임 원인 - 배란 장애",
    "불임 원인 - 여성 요인",
    "불임 원인 - 자궁경부 문제",
    "불임 원인 - 자궁내막증",
    "불임 원인 - 정자 농도",
    "불임 원인 - 정자 면역학적 요인",
    "불임 원인 - 정자 운동성",
    "불임 원인 - 정자 형태",
    "배아 생성 주요 이유",
    "총 시술 횟수",
    "클리닉 내 총 시술 횟수",
    "IVF 시술 횟수",
    "DI 시술 횟수",
    "총 임신 횟수",
    "IVF 임신 횟수",
    "DI 임신 횟수",
    "총 출산 횟수",
    "IVF 출산 횟수",
    "DI 출산 횟수",
    "난자 출처",
    "정자 출처",
    "난자 기증자 나이",
    "정자 기증자 나이",
    "동결 배아 사용 여부",
    "신선 배아 사용 여부",
    "기증 배아 사용 여부",
    "대리모 여부",
    "PGD 시술 여부",
    "PGS 시술 여부"
]

# %%
# 카테고리형 컬럼들을 문자열로 변환
for col in categorical_columns:
    X[col] = X[col].astype(str)
    test[col] = test[col].astype(str)

# %%
ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

X_train_encoded = X.copy()
X_train_encoded[categorical_columns] = ordinal_encoder.fit_transform(X[categorical_columns])

X_test_encoded = test.copy()
X_test_encoded[categorical_columns] = ordinal_encoder.transform(test[categorical_columns])

# %%
numeric_columns = [
    "임신 시도 또는 마지막 임신 경과 연수",
    "총 생성 배아 수",
    "미세주입된 난자 수",
    "미세주입에서 생성된 배아 수",
    "이식된 배아 수",
    "미세주입 배아 이식 수",
    "저장된 배아 수",
    "미세주입 후 저장된 배아 수",
    "해동된 배아 수",
    "해동 난자 수",
    "수집된 신선 난자 수",
    "저장된 신선 난자 수",
    "혼합된 난자 수",
    "파트너 정자와 혼합된 난자 수",
    "기증자 정자와 혼합된 난자 수",
    "난자 채취 경과일",
    "난자 해동 경과일",
    "난자 혼합 경과일",
    "배아 이식 경과일",
    "배아 해동 경과일"
]

# %%
X_train_encoded[numeric_columns] = X_train_encoded[numeric_columns].fillna(0)
X_test_encoded[numeric_columns] = X_test_encoded[numeric_columns].fillna(0)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_encoded, y, test_size=0.2, random_state=42, stratify=y
)

# %% [markdown]
# ### Train

# %% [markdown]
# Stacking model

# %%
# Optuna 최적화 함수 정의
def objective(trial):
    # RandomForest 하이퍼파라미터 튜닝
    rf_n_estimators = trial.suggest_int("rf_n_estimators", 50, 300)
    rf_max_depth = trial.suggest_int("rf_max_depth", 3, 20)
    
    # XGBoost 하이퍼파라미터 튜닝
    xgb_n_estimators = trial.suggest_int("xgb_n_estimators", 50, 300)
    xgb_max_depth = trial.suggest_int("xgb_max_depth", 3, 20)
    xgb_learning_rate = trial.suggest_float("xgb_learning_rate", 0.01, 0.3, log=True)
    
    # Logistic Regression 하이퍼파라미터 튜닝
    lr_C = trial.suggest_float("lr_C", 0.01, 10, log=True)

    # 베이스 모델 정의
    base_models = [
        ('rf', RandomForestClassifier(n_estimators=rf_n_estimators, max_depth=rf_max_depth, random_state=42, n_jobs=-1)),
        ('xgb', XGBClassifier(n_estimators=xgb_n_estimators, max_depth=xgb_max_depth, learning_rate=xgb_learning_rate, eval_metric='logloss', random_state=42, n_jobs=-1)),
        ('lr', LogisticRegression(C=lr_C, max_iter=10000, random_state=42))
    ]

    # 메타 모델 정의
    meta_model = LogisticRegression(max_iter=10000, random_state=42)

    # 스태킹 모델 구성
    stacking_clf = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=StratifiedKFold(n_splits=3))

    # AUC 기반 교차 검증 수행
    auc_scores = cross_val_score(stacking_clf, X_train, y_train, cv=StratifiedKFold(n_splits=3), scoring='roc_auc', n_jobs=-1)
    
    return np.mean(auc_scores)

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100, show_progress_bar = True)
# Out:
# [I 2025-02-20 00:22:03,388] A new study created in memory with name: no-name-8a995d77-c2c8-491a-9d14-a114db151687
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-02-20 00:23:19,205] Trial 0 finished with value: 0.7337700293167558 and parameters: {'rf_n_estimators': 83, 'rf_max_depth': 18, 'xgb_n_estimators': 107, 'xgb_max_depth': 15, 'xgb_learning_rate': 0.26234152553267853, 'lr_C': 0.015535740219361202}. Best is trial 0 with value: 0.7337700293167558.
# [I 2025-02-20 00:25:54,745] Trial 1 finished with value: 0.735816546711944 and parameters: {'rf_n_estimators': 136, 'rf_max_depth': 15, 'xgb_n_estimators': 245, 'xgb_max_depth': 17, 'xgb_learning_rate': 0.015196943130613295, 'lr_C': 7.35194038417909}. Best is trial 1 with value: 0.735816546711944.
# [I 2025-02-20 00
 'xgb_max_depth': 5, 'xgb_learning_rate': 0.08359909316012627, 'lr_C': 0.7519090786471442}. Best is trial 63 with value: 0.739261650102065.
# [I 2025-02-20 02:01:54,909] Trial 69 finished with value: 0.7391997376675657 and parameters: {'rf_n_estimators': 262, 'rf_max_depth': 19, 'xgb_n_estimators': 256, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.12007821378328709, 'lr_C': 1.7826220349594186}. Best is trial 63 with value: 0.739261650102065.
# [I 2025-02-20 02:04:06,742] Trial 70 finished with value: 0.7341760745940112 and parameters: {'rf_n_estimators': 260, 'rf_max_depth': 19, 'xgb_n_estimators': 233, 'xgb_max_depth': 15, 'xgb_learning_rate': 0.11671058462852453, 'lr_C': 1.7066746172912355}. Best is trial 63 with value: 0.739261650102065.
# [I 2025-02-20 02:06:10,285] Trial 71 finished with value: 0.7391884211380164 and parameters: {'rf_n_estimators': 288, 'rf_max_depth': 18, 'xgb_n_estimators': 259, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.09555476598639806, 'lr_C': 3.1038090951098947}. Best is trial 63 with value: 0.739261650102065.
# [I 2025-02-20 02:08:11,306] Trial 72 finished with value: 0.7388450512517206 and parameters: {'rf_n_estimators': 290, 'rf_max_depth': 18, 'xgb_n_estimators': 257, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.12694441150997077, 'lr_C': 0.624034952931696}. Best is trial 63 with value: 0.739261650102065.
# [I 2025-02-20 02:10:03,523] Trial 73 finished with value: 0.737670062814789 and parameters: {'rf_n_estimators': 262, 'rf_max_depth': 20, 'xgb_n_estimators': 275, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.1474986906148661, 'lr_C': 1.8885215102703823}. Best is trial 63 with value: 0.739261650102065.
# [I 2025-02-20 02:12:00,811] Trial 74 finished with value: 0.7392744996138157 and parameters: {'rf_n_estimators': 280, 'rf_max_depth': 16, 'xgb_n_estimators': 255, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.08323661543877357, 'lr_C': 4.291082978430574}. Best is trial 74 with value: 0.7392744996138157.
# [I 2025-02-20 02:13:58,022] Trial 75 finished with value: 0.7392613794201819 and parameters: {'rf_n_estimators': 278, 'rf_max_depth': 16, 'xgb_n_estimators': 242, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.08026690241744734, 'lr_C': 3.931128730005841}. Best is trial 74 with value: 0.7392744996138157.
# [I 2025-02-20 02:15:48,927] Trial 76 finished with value: 0.7391775485759805 and parameters: {'rf_n_estimators': 248, 'rf_max_depth': 15, 'xgb_n_estimators': 235, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.08236352408766932, 'lr_C': 4.325214323023096}. Best is trial 74 with value: 0.7392744996138157.
# [I 2025-02-20 02:17:45,529] Trial 77 finished with value: 0.739091119775151 and parameters: {'rf_n_estimators': 278, 'rf_max_depth': 16, 'xgb_n_estimators': 246, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.06445874147495609, 'lr_C': 4.933955729926301}. Best is trial 74 with value: 0.7392744996138157.
# [I 2025-02-20 02:19:45,539] Trial 78 finished with value: 0.7382734240642232 and parameters: {'rf_n_estimators': 263, 'rf_max_depth': 16, 'xgb_n_estimators': 278, 'xgb_max_depth': 6, 'xgb_learning_rate': 0.07751821383653547, 'lr_C': 1.3951146691586935}. Best is trial 74 with value: 0.7392744996138157.
# [I 2025-02-20 02:21:37,916] Trial 79 finished with value: 0.7386629569803752 and parameters: {'rf_n_estimators': 251, 'rf_max_depth': 15, 'xgb_n_estimators': 218, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.11097127559022488, 'lr_C': 1.15408436847248}. Best is trial 74 with value: 0.7392744996138157.
# [I 2025-02-20 02:23:29,636] Trial 80 finished with value: 0.7388155756226672 and parameters: {'rf_n_estimators': 277, 'rf_max_depth': 13, 'xgb_n_estimators': 260, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.08857482418957419, 'lr_C': 3.2244169758273853}. Best is trial 74 with value: 0.7392744996138157.
# [I 2025-02-20 02:25:28,272] Trial 81 finished with value: 0.7394499305608445 and parameters: {'rf_n_estimators': 281, 'rf_max_depth': 17, 'xgb_n_estimators': 250, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.07545332061601703, 'lr_C': 2.240711890786483}. Best is trial 81 with value: 0.7394499305608445.
# [I 2025-02-20 02:27:22,473] Trial 82 finished with value: 0.7393961941765137 and parameters: {'rf_n_estimators': 241, 'rf_max_depth': 17, 'xgb_n_estimators': 247, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.07284773324137697, 'lr_C': 2.0088920311300345}. Best is trial 81 with value: 0.7394499305608445.
# [I 2025-02-20 02:29:28,466] Trial 83 finished with value: 0.739142798024972 and parameters: {'rf_n_estimators': 293, 'rf_max_depth': 19, 'xgb_n_estimators': 249, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.0720254232566779, 'lr_C': 2.041112602735459}. Best is trial 81 with value: 0.7394499305608445.
# [I 2025-02-20 02:31:25,483] Trial 84 finished with value: 0.7392127605547995 and parameters: {'rf_n_estimators': 271, 'rf_max_depth': 17, 'xgb_n_estimators': 235, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.07187929877253603, 'lr_C': 1.0146893533302723}. Best is trial 81 with value: 0.7394499305608445.
# [I 2025-02-20 02:33:16,695] Trial 85 finished with value: 0.7390348363838597 and parameters: {'rf_n_estimators': 240, 'rf_max_depth': 17, 'xgb_n_estimators': 236, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.06135846518836223, 'lr_C': 0.9756303493939302}. Best is trial 81 with value: 0.7394499305608445.
# [I 2025-02-20 02:35:11,811] Trial 86 finished with value: 0.739305242840295 and parameters: {'rf_n_estimators': 274, 'rf_max_depth': 17, 'xgb_n_estimators': 226, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.08702127492544293, 'lr_C': 0.7273635167035296}. Best is trial 81 with value: 0.7394499305608445.
# [I 2025-02-20 02:37:10,567] Trial 87 finished with value: 0.7387931083005194 and parameters: {'rf_n_estimators': 299, 'rf_max_depth': 16, 'xgb_n_estimators': 226, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.08841402237431199, 'lr_C': 0.6584889402187802}. Best is trial 81 with value: 0.7394499305608445.
# [I 2025-02-20 02:39:05,505] Trial 88 finished with value: 0.73834221127382 and parameters: {'rf_n_estimators': 273, 'rf_max_depth': 15, 'xgb_n_estimators': 266, 'xgb_max_depth': 6, 'xgb_learning_rate': 0.07936597294942568, 'lr_C': 0.43613792165817955}. Best is trial 81 with value: 0.7394499305608445.
# [I 2025-02-20 02:40:58,500] Trial 89 finished with value: 0.7389727487534348 and parameters: {'rf_n_estimators': 293, 'rf_max_depth': 14, 'xgb_n_estimators': 202, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.10794843212978503, 'lr_C': 3.1077750130438093}. Best is trial 81 with value: 0.7394499305608445.
# [I 2025-02-20 02:42:47,851] Trial 90 finished with value: 0.7395508427437373 and parameters: {'rf_n_estimators': 254, 'rf_max_depth': 18, 'xgb_n_estimators': 244, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.06548201380816693, 'lr_C': 2.1656133988420163}. Best is trial 90 with value: 0.7395508427437373.
# [I 2025-02-20 02:44:33,318] Trial 91 finished with value: 0.7394077953064215 and parameters: {'rf_n_estimators': 253, 'rf_max_depth': 18, 'xgb_n_estimators': 241, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.06858360712193598, 'lr_C': 2.1901647581072403}. Best is trial 90 with value: 0.7395508427437373.
# [I 2025-02-20 02:46:17,289] Trial 92 finished with value: 0.7392161718456572 and parameters: {'rf_n_estimators': 253, 'rf_max_depth': 18, 'xgb_n_estimators': 251, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.06752067976860948, 'lr_C': 1.603522737787688}. Best is trial 90 with value: 0.7395508427437373.
# [I 2025-02-20 02:47:58,777] Trial 93 finished with value: 0.7394385148126755 and parameters: {'rf_n_estimators': 240, 'rf_max_depth': 17, 'xgb_n_estimators': 244, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.05757997992577777, 'lr_C': 1.1946696029600836}. Best is trial 90 with value: 0.7395508427437373.
# [I 2025-02-20 02:50:01,355] Trial 94 finished with value: 0.7350755678877811 and parameters: {'rf_n_estimators': 239, 'rf_max_depth': 17, 'xgb_n_estimators': 227, 'xgb_max_depth': 16, 'xgb_learning_rate': 0.05806496495940979, 'lr_C': 1.199336805957262}. Best is trial 90 with value: 0.7395508427437373.
# [I 2025-02-20 02:51:43,552] Trial 95 finished with value: 0.7392597946592881 and parameters: {'rf_n_estimators': 230, 'rf_max_depth': 17, 'xgb_n_estimators': 242, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.05027764521770369, 'lr_C': 3.4275805370610817}. Best is trial 90 with value: 0.7395508427437373.
# [I 2025-02-20 02:53:25,974] Trial 96 finished with value: 0.7393274321096509 and parameters: {'rf_n_estimators': 226, 'rf_max_depth': 17, 'xgb_n_estimators': 242, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.05030945188108957, 'lr_C': 5.066650750999346}. Best is trial 90 with value: 0.7395508427437373.
# [I 2025-02-20 02:55:10,741] Trial 97 finished with value: 0.7386480903436491 and parameters: {'rf_n_estimators': 244, 'rf_max_depth': 19, 'xgb_n_estimators': 243, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.04345916273040806, 'lr_C': 5.1744540362645015}. Best is trial 90 with value: 0.7395508427437373.
# [I 2025-02-20 02:56:52,573] Trial 98 finished with value: 0.7387578338775181 and parameters: {'rf_n_estimators': 233, 'rf_max_depth': 16, 'xgb_n_estimators': 268, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.07358077017021568, 'lr_C': 2.1765691753388663}. Best is trial 90 with value: 0.7395508427437373.
# [I 2025-02-20 02:58:31,738] Trial 99 finished with value: 0.7394478264554124 and parameters: {'rf_n_estimators': 218, 'rf_max_depth': 17, 'xgb_n_estimators': 211, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.06545771991801864, 'lr_C': 1.9635968977940192}. Best is trial 90 with value: 0.7395508427437373.

# %%
# 최적 하이퍼파라미터 출력
print("Best hyperparameters:", study.best_params)
# Out:
# Best hyperparameters: {'rf_n_estimators': 254, 'rf_max_depth': 18, 'xgb_n_estimators': 244, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.06548201380816693, 'lr_C': 2.1656133988420163}

# %%
# 최적 하이퍼파라미터로 모델 학습
best_params = study.best_params
rf_best = RandomForestClassifier(n_estimators=best_params["rf_n_estimators"], max_depth=best_params["rf_max_depth"], random_state=42)
xgb_best = XGBClassifier(n_estimators=best_params["xgb_n_estimators"], max_depth=best_params["xgb_max_depth"], learning_rate=best_params["xgb_learning_rate"], use_label_encoder=False, eval_metric='logloss', random_state=42)
lr_best = LogisticRegression(C=best_params["lr_C"], max_iter=1000, random_state=42)

# 최적화된 스태킹 모델 생성
model = StackingClassifier(estimators=[('rf', rf_best), ('xgb', xgb_best), ('lr', lr_best)], final_estimator=LogisticRegression(max_iter=1000, random_state=42), cv=StratifiedKFold(n_splits=5))

# %%
model.fit(X_train_encoded, y)
# Out:
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [03:05:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [03:09:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [03:09:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [03:09:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [03:09:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [03:09:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# StackingClassifier(cv=StratifiedKFold(n_splits=5,
#         random_state=RandomState(MT19937) at 0x26CC57DBC40, shuffle=False),
#                    estimators=[('rf',
#                                 RandomForestClassifier(max_depth=18,
#                                                        n_estimators=254,
#                                                        random_state=42)),
#                                ('xgb',
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               device=None,
#                                               earl...
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None, max_depth=4,
#                                               max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=244, n_jobs=None,
#                                               num_parallel_tree=None,
#                                               random_state=42, ...)),
#                                ('lr',
#                                 LogisticRegression(C=2.1656133988420163,
#                                                    max_iter=1000,
#                                                    random_state=42))],
#                    final_estimator=LogisticRegression(max_iter=1000,
#                                                       random_state=42))

# %%
from sklearn.metrics import accuracy_score, roc_auc_score

# 예측
y_train_pred = model.predict(X_train_encoded)
y_train_proba = model.predict_proba(X_train_encoded)[:, 1]  # ROC-AUC Score 계산용

# 평가
accuracy = accuracy_score(y, y_train_pred)
roc_auc = roc_auc_score(y, y_train_proba)

# 출력
print(f"Model - Accuracy: {accuracy:.4f}")
print(f"Model - ROC-AUC Score: {roc_auc:.4f}")
# Out:
# Model - Accuracy: 0.7632
# Model - ROC-AUC Score: 0.7785

# %% [markdown]
# ### Predict

# %%
pred_proba = model.predict_proba(X_test_encoded)[:, 1]

# %% [markdown]
# ### Model Save

# %%
import joblib

# 모델 저장
joblib.dump(model, './stacking_optimization_model.pkl')

# # 저장한 모델 불러오기
# loaded_model = joblib.load('./stacking_model.pkl')
# Out:
# ['./stacking_optimization_model.pkl']

# %% [markdown]
# ### Submission

# %%
sample_submission = pd.read_csv('./Data/sample_submission.csv')
sample_submission['probability'] = pred_proba

# %%
sample_submission.to_csv('./Stacking_optimization_submit.csv', index=False)
