# %% [markdown]
# ### Import

# %%
# !pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from lightgbm) (2.2.2)
# Requirement already satisfied: scipy in c:\users\vhehr\.conda\envs\lgaimers6\lib\site-packages (from lightgbm) (1.15.1)
# Downloading lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 41.8 MB/s eta 0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import OrdinalEncoder

import joblib
import optuna

from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier, ExtraTreesClassifier
import lightgbm as lgb
import xgboost as xgb

# %% [markdown]
# ### Data Load

# %%
train = pd.read_csv('./Data/train.csv').drop(columns=['ID'])
test = pd.read_csv('./Data/test.csv').drop(columns=['ID'])

# %%
X = train.drop('임신 성공 여부', axis=1)
y = train['임신 성공 여부']

# %% [markdown]
# ### Data Pre-processing

# %%
categorical_columns = [
    "시술 시기 코드",
    "시술 당시 나이",
    "시술 유형",
    "특정 시술 유형",
    "배란 자극 여부",
    "배란 유도 유형",
    "단일 배아 이식 여부",
    "착상 전 유전 검사 사용 여부",
    "착상 전 유전 진단 사용 여부",
    "남성 주 불임 원인",
    "남성 부 불임 원인",
    "여성 주 불임 원인",
    "여성 부 불임 원인",
    "부부 주 불임 원인",
    "부부 부 불임 원인",
    "불명확 불임 원인",
    "불임 원인 - 난관 질환",
    "불임 원인 - 남성 요인",
    "불임 원인 - 배란 장애",
    "불임 원인 - 여성 요인",
    "불임 원인 - 자궁경부 문제",
    "불임 원인 - 자궁내막증",
    "불임 원인 - 정자 농도",
    "불임 원인 - 정자 면역학적 요인",
    "불임 원인 - 정자 운동성",
    "불임 원인 - 정자 형태",
    "배아 생성 주요 이유",
    "총 시술 횟수",
    "클리닉 내 총 시술 횟수",
    "IVF 시술 횟수",
    "DI 시술 횟수",
    "총 임신 횟수",
    "IVF 임신 횟수",
    "DI 임신 횟수",
    "총 출산 횟수",
    "IVF 출산 횟수",
    "DI 출산 횟수",
    "난자 출처",
    "정자 출처",
    "난자 기증자 나이",
    "정자 기증자 나이",
    "동결 배아 사용 여부",
    "신선 배아 사용 여부",
    "기증 배아 사용 여부",
    "대리모 여부",
    "PGD 시술 여부",
    "PGS 시술 여부"
]

# %%
# 카테고리형 컬럼들을 문자열로 변환
for col in categorical_columns:
    X[col] = X[col].astype(str)
    test[col] = test[col].astype(str)

# %%
ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

X_train_encoded = X.copy()
X_train_encoded[categorical_columns] = ordinal_encoder.fit_transform(X[categorical_columns])

X_test_encoded = test.copy()
X_test_encoded[categorical_columns] = ordinal_encoder.transform(test[categorical_columns])

# %%
numeric_columns = [
    "임신 시도 또는 마지막 임신 경과 연수",
    "총 생성 배아 수",
    "미세주입된 난자 수",
    "미세주입에서 생성된 배아 수",
    "이식된 배아 수",
    "미세주입 배아 이식 수",
    "저장된 배아 수",
    "미세주입 후 저장된 배아 수",
    "해동된 배아 수",
    "해동 난자 수",
    "수집된 신선 난자 수",
    "저장된 신선 난자 수",
    "혼합된 난자 수",
    "파트너 정자와 혼합된 난자 수",
    "기증자 정자와 혼합된 난자 수",
    "난자 채취 경과일",
    "난자 해동 경과일",
    "난자 혼합 경과일",
    "배아 이식 경과일",
    "배아 해동 경과일"
]

# %%
numeric_columns = [col for col in numeric_columns if col in X.columns]

X_train_encoded[numeric_columns] = X_train_encoded[numeric_columns].fillna(0)
X_test_encoded[numeric_columns] = X_test_encoded[numeric_columns].fillna(0)

# %%
from collections import Counter

# 클래스별 샘플 개수 출력
class_counts = Counter(y)
print(class_counts)
# Out:
# Counter({0: 190123, 1: 66228})

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_encoded, y, test_size=0.2, random_state=42, stratify=y
)

# %% [markdown]
# ### Train

# %% [markdown]
# Lightgbm

# %%
import joblib

opti_trial = 10

# 저장된 모델 불러오기
lgb_model = joblib.load('./LightGBM_boosting2.pkl')

# 3. Optuna로 XGBoost 최적화
def optimize_xgb(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 10)
    }
    model = xgb.XGBClassifier(**param, random_state=42, eval_metric='logloss')
    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='roc_auc')
    return scores.mean()

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(optimize_xgb, n_trials=opti_trial, show_progress_bar=True)
xgb_best_params = study_xgb.best_params

# 4. Optuna로 ExtraTreesClassifier 최적화
def optimize_extra(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10)
    }
    model = ExtraTreesClassifier(**param, random_state=42)
    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='roc_auc')
    return scores.mean()

study_extra = optuna.create_study(direction='maximize')
study_extra.optimize(optimize_extra, n_trials=opti_trial, show_progress_bar=True)
extra_best_params = study_extra.best_params

# 5. Optuna로 Meta Model (LogisticRegression) 최적화
def optimize_meta(trial):
    param = {
        'C': trial.suggest_loguniform('C', 0.01, 10.0),
        'penalty': trial.suggest_categorical('penalty', ['l2'])
    }
    model = LogisticRegression(**param, random_state=42)
    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='roc_auc')
    return scores.mean()

study_meta = optuna.create_study(direction='maximize')
study_meta.optimize(optimize_meta, n_trials=opti_trial, show_progress_bar=True)
meta_best_params = study_meta.best_params

# 6. 최적화된 하이퍼파라미터로 모델 구성
xgb_model = xgb.XGBClassifier(**xgb_best_params, random_state=42, eval_metric='logloss')
extra_model = ExtraTreesClassifier(**extra_best_params, random_state=42)
meta_model = LogisticRegression(**meta_best_params, random_state=42)

# 7. Stacking Classifier 구성
stacking_clf = StackingClassifier(
    estimators=[
        ('lgb', lgb_model),
        ('xgb', xgb_model),
        ('extra', extra_model)
    ],
    final_estimator=meta_model,
    cv=KFold(n_splits=5, shuffle=True, random_state=42),
    n_jobs=-1
)
# Out:
# [I 2025-02-26 23:30:17,428] A new study created in memory with name: no-name-07a20711-3feb-44fc-ac61-264289af742b
#   0%|          | 0/10 [00:00<?, ?it/s]
# C:\Users\vhehr\AppData\Local\Temp\ipykernel_22912\760316175.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-26 23:30:26,436] Trial 0 finished with value: 0.7390667822973718 and parameters: {'n_estimators': 423, 'learning_rate': 0.11273811648754437, 'max_depth': 4}. Best is trial 0 with value: 0.7390667822973718.
# C:\Users\vhehr\AppData\Local\Temp\ipykernel_22912\760316175.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-26 23:30:37,405] Trial 1 finished with value: 0.7370211010948933 and parameters: {'n_estimators': 268, 'learning_rate': 0.02970296633225808, 'max_depth': 9}. Best is trial 0 with value: 0.7390667822973718.
# C:\Users\vhehr\AppData\Local\Temp\ipykernel_22912\760316175.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-26 23:30:54,880] Trial 2 finished with value: 0.7367991230992451 and parameters: {'n_estimators': 486, 'learning_rate': 0.020144729075373843, 'max_depth': 9}. Best is trial 0 with value: 0.7390667822973718.
# C:\Users\vhehr\AppData\Local\Temp\ipykernel_22912\760316175.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:30:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-26 23:31:04,433] Trial 3 finished with value: 0.7333723119263811 and parameters: {'n_estimators': 327, 'learning_rate': 0.09755277405677476, 'max_depth': 8}. Best is trial 0 with value: 0.7390667822973718.
# C:\Users\vhehr\AppData\Local\Temp\ipykernel_22912\760316175.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-26 23:31:16,754] Trial 4 finished with value: 0.729973587723521 and parameters: {'n_estimators': 374, 'learning_rate': 0.06940268576555354, 'max_depth': 10}. Best is trial 0 with value: 0.7390667822973718.
# C:\Users\vhehr\AppData\Local\Temp\ipykernel_22912\760316175.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-26 23:31:24,264] Trial 5 finished with value: 0.7397867655367976 and parameters: {'n_estimators': 353, 'learning_rate': 0.07999021163010435, 'max_depth': 3}. Best is trial 5 with value: 0.7397867655367976.
# C:\Users\vhehr\AppData\Local\Temp\ipykernel_22912\760316175.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-26 23:31:31,980] Trial 6 finished with value: 0.7362454825306536 and parameters: {'n_estimators': 327, 'learning_rate': 0.19122922334825088, 'max_depth': 5}. Best is trial 5 with value: 0.7397867655367976.
# C:\Users\vhehr\AppData\Local\Temp\ipykernel_22912\760316175.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-26 23:31:35,769] Trial 7 finished with value: 0.7393436059719092 and parameters: {'n_estimators': 152, 'learning_rate': 0.28110022763062825, 'max_depth': 3}. Best is trial 5 with value: 0.7397867655367976.
# C:\Users\vhehr\AppData\Local\Temp\ipykernel_22912\760316175.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-26 23:31:47,898] Trial 8 finished with value: 0.7309110122745192 and parameters: {'n_estimators': 444, 'learning_rate': 0.10364405919139609, 'max_depth': 8}. Best is trial 5 with value: 0.7397867655367976.
# C:\Users\vhehr\AppData\Local\Temp\ipykernel_22912\760316175.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:31:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-26 23:31:52,521] A new study created in memory with name: no-name-64d8d6e4-c635-4c98-b7d7-92c300df57ef
# [I 2025-02-26 23:31:52,517] Trial 9 finished with value: 0.7390253919969443 and parameters: {'n_estimators': 162, 'learning_rate': 0.05370202699833404, 'max_depth': 4}. Best is trial 5 with value: 0.7397867655367976.
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2025-02-26 23:32:56,088] Trial 0 finished with value: 0.7216428961584442 and parameters: {'n_estimators': 151, 'max_depth': 8, 'min_samples_split': 9}. Best is trial 0 with value: 0.7216428961584442.

# %%
stacking_clf.fit(X_train_encoded, y)
# Out:
# StackingClassifier(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                    estimators=[('lgb',
#                                 LGBMClassifier(colsample_bytree=0.6283518615400887,
#                                                learning_rate=0.020414102740183366,
#                                                max_depth=9,
#                                                min_child_samples=14,
#                                                n_estimators=1020, num_leaves=35,
#                                                reg_alpha=9.422816220857865,
#                                                reg_lambda=3.965116334727029e-05,
#                                                subsample=0.8361505791254964)),
#                                ('xgb',
#                                 XGBClassifie...
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None,
#                                               max_depth=None, max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=None, n_jobs=None,
#                                               num_parallel_tree=None,
#                                               random_state=42, ...)),
#                                ('extra',
#                                 ExtraTreesClassifier(random_state=42))],
#                    final_estimator=LogisticRegression(random_state=42),
#                    n_jobs=-1)

# %%
# 피처 이름 공백 제거
X.columns = X.columns.str.replace(" ", "_")

def objective(trial):
    # 사전에 저장된 LightGBM 모델 불러오기 (이미 학습된 모델)
    pre_trained_lgb = joblib.load('./LightGBM_boosting2.pkl')
    
    age_weight = trial.suggest_float("age_weight", 1.0, 3.0, step=0.1)
    
    # XGBoost 하이퍼파라미터 최적화
    xgb_params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 200),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_loguniform("learning_rate", 1e-3, 0.3),
        "feature_weights": [age_weight if col == '시술 당시 나이' else 1 for col in X_train.columns]
    }
    xgb_model = XGBClassifier(**xgb_params,
                              random_state=42,
                              use_label_encoder=False,
                              eval_metric='logloss')
    
    # 메타 모델 (로지스틱 회귀) 하이퍼파라미터 최적화
    lr_C = trial.suggest_loguniform('lr_C', 1e-3, 1e2)
    meta_model = LogisticRegression(C=lr_C, random_state=42, max_iter=1000)
    
    # 스태킹 모델 구성: 사전에 학습된 LightGBM 모델과 최적화 대상 XGBoost 모델 사용
    estimators = [
        ('lgb', pre_trained_lgb),
        ('xgb', xgb_model)
    ]
    
    stack_model = StackingClassifier(estimators=estimators,
                                     final_estimator=meta_model,
                                     cv=5,          # 내부 교차 검증 사용
                                     passthrough=False,
                                     n_jobs=-1)
    
    # 5-fold 교차 검증을 통해 평균 정확도 측정
    score = cross_val_score(stack_model, X_train, y_train, cv=5, scoring='roc_auc').mean()
    return score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from lightgbm import early_stopping, log_evaluation
#       3 # 피처 이름 공백 제거
# ----> 4 X.columns = X.columns.str.replace(" ", "_")
#       6 def objective(trial):
#       7     # 사전에 저장된 LightGBM 모델 불러오기 (이미 학습된 모델)
#       8     pre_trained_lgb = joblib.load('./LightGBM_boosting2.pkl')
#
# NameError: name 'X' is not defined

# %%
import warnings

# 불필요한 경고 제거
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.filterwarnings("ignore", category=UserWarning, module="lightbgm")

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2025-02-23 11:58:34,197] A new study created in memory with name: no-name-de154bb2-cbdb-4efa-b252-7584e8362012
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-02-23 12:01:00,983] Trial 0 finished with value: 0.7441242441973863 and parameters: {'age_weight': 1.8, 'n_estimators': 86, 'max_depth': 10, 'learning_rate': 0.004049289475108182, 'lr_C': 0.4357079289600887}. Best is trial 0 with value: 0.7441242441973863.
# [I 2025-02-23 12:03:35,021] Trial 1 finished with value: 0.7436707626292179 and parameters: {'age_weight': 3.0, 'n_estimators': 181, 'max_depth': 9, 'learning_rate': 0.009563974126100076, 'lr_C': 83.81433121876083}. Best is trial 0 with value: 0.7441242441973863.
# [I 2025-02-23 12:05:41,879] Trial 2 finished with value: 0.7440169689877121 and parameters: {'age_weight': 1.1, 'n_estimators': 177, 'max_depth': 5, 'learning_rate': 0.07844044464156676, 'lr_C': 0.5942985777569691}. Best is trial 0 with value: 0.7441242441973863.
# [I 2025-02-23 12:09:12,419] Trial 3 finished with value: 0.7448166569143748 and parameters: {'age_weight': 2.7, 'n_estimators': 112, 'max_depth': 5, 'learning_rate': 0.04889844125649485, 'lr_C': 0.001893856595716437}. Best is trial 3 with value: 0.7448166569143748.
# [I 2025-02-23 12:13:54,445] Trial 4 finished with value: 0.7441486249268577 and parameters: {'age_weight': 1.2, 'n_estimators': 143, 'max_depth': 9, 'learning_rate': 0.0023423488796474475, 'lr_C': 0.7295865824834965}. Best is trial 3 with value: 0.7448166569143748.
# [I 2025-02-23 12:16:24,929] Trial 5 finished with value: 0.7451969962941292 and parameters: {'age_weight': 2.3, 'n_estimators': 175, 'max_depth': 3, 'learning_rate': 0.0015006817936068166, 'lr_C': 0.021271581599293085}. Best is trial 5 with value: 0.7451969962941292.
# [I 2025-02-23 12:19:59,377] Trial 6 finished with value: 0.7456651062999805 and parameters: {'age_weight': 2.5, 'n_estimators': 99, 'max_depth': 8, 'learning_rate': 0.004050286755351693, 'lr_C': 0.011841036203744474}. Best is trial 6 with value: 0.7456651062999805.
# [I 2025-02-23 12:23:08,467] Trial 7 finished with value: 0.7445240881607178 and parameters: {'age_weight': 1.9, 'n_estimators': 63, 'max_depth': 4, 'learning_rate': 0.0014224292493643608, 'lr_C': 74.23044409540994}. Best is trial 6 with value: 0.7456651062999805.
# [I 2025-02-23 12:25:28,547] Trial 8 finished with value: 0.7437390286717379 and parameters: {'age_weight': 2.8, 'n_estimators': 153, 'max_depth': 8, 'learning_rate': 0.0033484272443094405, 'lr_C': 56.699053912302276}. Best is trial 6 with value: 0.7456651062999805.
# [I 2025-02-23 12:28:01,178] Trial 9 finished with value: 0.7441486249268577 and parameters: {'age_weight': 2.8, 'n_estimators': 96, 'max_depth': 10, 'learning_rate': 0.04334580759024115, 'lr_C': 36.39521645321068}. Best is trial 6 with value: 0.7456651062999805.
# [I 2025-02-23 12:30:00,551] Trial 10 finished with value: 0.7446898771211234 and parameters: {'age_weight': 2.3, 'n_estimators': 50, 'max_depth': 7, 'learning_rate': 0.01440350869631106, 'lr_C': 0.024657461053089705}. Best is trial 6 with value: 0.7456651062999805.
# [I 2025-02-23 12:31:54,608] Trial 11 finished with value: 0.7454505558806319 and parameters: {'age_weight': 2.3, 'n_estimators': 197, 'max_depth': 3, 'learning_rate': 0.29729950385904286, 'lr_C': 0.009769391968265886}. Best is trial 6 with value: 0.7456651062999805.
# [I 2025-02-23 12:34:04,655] Trial 12 finished with value: 0.7433635654378781 and parameters: {'age_weight': 2.3, 'n_estimators': 199, 'max_depth': 6, 'learning_rate': 0.20052382535639138, 'lr_C': 0.0010217390687518482}. Best is trial 6 with value: 0.7456651062999805.
# [I 2025-02-23 12:36:26,779] Trial 13 finished with value: 0.744714257850595 and parameters: {'age_weight': 1.6, 'n_estimators': 129, 'max_depth': 7, 'learning_rate': 0.2604818263135807, 'lr_C': 0.015708448442744893}. Best is trial 6 with value: 0.7456651062999805.
# [I 2025-02-23 12:38:29,894] Trial 14 finished with value: 0.7435634874195436 and parameters: {'age_weight': 2.4000000000000004, 'n_estimators': 96, 'max_depth': 3, 'learning_rate': 0.008029790327347979, 'lr_C': 0.05252211791948959}. Best is trial 6 with value: 0.7456651062999805.
# [I 2025-02-23 12:40:44,962] Trial 15 finished with value: 0.7458016383850203 and parameters: {'age_weight': 2.5, 'n_estimators': 76, 'max_depth': 8, 'learning_rate': 0.028336437534534388, 'lr_C': 0.005863504146778031}. Best is trial 15 with value: 0.7458016383850203.
# [I 2025-02-23 12:42:47,484] Trial 16 finished with value: 0.7462307392237175 and parameters: {'age_weight': 2.6, 'n_estimators': 76, 'max_depth': 8, 'learning_rate': 0.023591745626466546, 'lr_C': 0.0047399781917424845}. Best is trial 16 with value: 0.7462307392237175.
# [I 2025-02-23 12:45:02,397] Trial 17 finished with value: 0.7436853910669007 and parameters: {'age_weight': 2.1, 'n_estimators': 71, 'max_depth': 8, 'learning_rate': 0.028786418273714164, 'lr_C': 0.11175189825522273}. Best is trial 16 with value: 0.7462307392237175.
# [I 2025-02-23 12:46:53,683] Trial 18 finished with value: 0.7459869319290033 and parameters: {'age_weight': 2.6, 'n_estimators': 76, 'max_depth': 6, 'learning_rate': 0.10761103949668395, 'lr_C': 0.0034322654406408752}. Best is trial 16 with value: 0.7462307392237175.
# [I 2025-02-23 12:50:39,450] Trial 19 finished with value: 0.7439828359664521 and parameters: {'age_weight': 3.0, 'n_estimators': 116, 'max_depth': 6, 'learning_rate': 0.09953339469192217, 'lr_C': 8.828598696625338}. Best is trial 16 with value: 0.7462307392237175.
# [I 2025-02-23 12:52:34,296] Trial 20 finished with value: 0.7459918080748976 and parameters: {'age_weight': 1.5, 'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.11078988742099061, 'lr_C': 0.002968119243646745}. Best is trial 16 with value: 0.7462307392237175.
# [I 2025-02-23 12:54:33,582] Trial 21 finished with value: 0.7462941291203433 and parameters: {'age_weight': 1.5, 'n_estimators': 55, 'max_depth': 5, 'learning_rate': 0.12891682151367456, 'lr_C': 0.0034113886132639726}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 12:56:34,234] Trial 22 finished with value: 0.7459381704700605 and parameters: {'age_weight': 1.4, 'n_estimators': 51, 'max_depth': 5, 'learning_rate': 0.1265478845295246, 'lr_C': 0.002597625010788352}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 12:58:47,352] Trial 23 finished with value: 0.7422664326116637 and parameters: {'age_weight': 1.5, 'n_estimators': 61, 'max_depth': 4, 'learning_rate': 0.05299747204356938, 'lr_C': 0.0010373900205170035}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:00:40,410] Trial 24 finished with value: 0.7437390286717378 and parameters: {'age_weight': 1.3, 'n_estimators': 59, 'max_depth': 4, 'learning_rate': 0.15965120675739022, 'lr_C': 0.06335198731694452}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:02:41,205] Trial 25 finished with value: 0.7460990832845719 and parameters: {'age_weight': 1.0, 'n_estimators': 79, 'max_depth': 5, 'learning_rate': 0.02174629981580472, 'lr_C': 0.004438218287816102}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:04:43,850] Trial 26 finished with value: 0.7432855471035692 and parameters: {'age_weight': 1.7000000000000002, 'n_estimators': 83, 'max_depth': 7, 'learning_rate': 0.014817907055714766, 'lr_C': 2.4235295390506715}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:07:08,041] Trial 27 finished with value: 0.7433684415837722 and parameters: {'age_weight': 1.0, 'n_estimators': 87, 'max_depth': 6, 'learning_rate': 0.024484995048112683, 'lr_C': 0.21787271829669233}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:09:10,076] Trial 28 finished with value: 0.7456748585917691 and parameters: {'age_weight': 2.1, 'n_estimators': 103, 'max_depth': 4, 'learning_rate': 0.07004858654297802, 'lr_C': 0.006770726337257029}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:11:09,278] Trial 29 finished with value: 0.744685000975229 and parameters: {'age_weight': 1.8, 'n_estimators': 85, 'max_depth': 9, 'learning_rate': 0.0061619180010678044, 'lr_C': 0.03176237688378643}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:13:14,978] Trial 30 finished with value: 0.7431343865808466 and parameters: {'age_weight': 1.3, 'n_estimators': 66, 'max_depth': 5, 'learning_rate': 0.018077947553563227, 'lr_C': 0.24843968676931877}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:15:20,994] Trial 31 finished with value: 0.7462209869319291 and parameters: {'age_weight': 1.6, 'n_estimators': 51, 'max_depth': 5, 'learning_rate': 0.04115656899351857, 'lr_C': 0.004067015399882677}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:17:24,932] Trial 32 finished with value: 0.746016188804369 and parameters: {'age_weight': 1.0, 'n_estimators': 74, 'max_depth': 6, 'learning_rate': 0.03816681730229271, 'lr_C': 0.005092334636252688}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:19:33,735] Trial 33 finished with value: 0.7427101618880437 and parameters: {'age_weight': 2.0, 'n_estimators': 57, 'max_depth': 5, 'learning_rate': 0.01088195710709283, 'lr_C': 0.0016621336284276624}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:21:32,811] Trial 34 finished with value: 0.7456456017164033 and parameters: {'age_weight': 1.7000000000000002, 'n_estimators': 68, 'max_depth': 4, 'learning_rate': 0.06732171177865091, 'lr_C': 0.00779015916954313}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:23:48,462] Trial 35 finished with value: 0.746220986931929 and parameters: {'age_weight': 1.2, 'n_estimators': 91, 'max_depth': 7, 'learning_rate': 0.02074656098249856, 'lr_C': 0.0034078407842869037}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:25:43,658] Trial 36 finished with value: 0.7447825238931148 and parameters: {'age_weight': 1.2, 'n_estimators': 109, 'max_depth': 7, 'learning_rate': 0.03484054803927973, 'lr_C': 0.0018050896797058705}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:28:11,440] Trial 37 finished with value: 0.7446216110786035 and parameters: {'age_weight': 1.4, 'n_estimators': 91, 'max_depth': 9, 'learning_rate': 0.06005907154933994, 'lr_C': 0.01338414519742419}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:30:25,144] Trial 38 finished with value: 0.7434025746050322 and parameters: {'age_weight': 1.2, 'n_estimators': 131, 'max_depth': 7, 'learning_rate': 0.009934362718083668, 'lr_C': 1.5357390260722112}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:32:24,047] Trial 39 finished with value: 0.744802028476692 and parameters: {'age_weight': 1.6, 'n_estimators': 61, 'max_depth': 8, 'learning_rate': 0.0064872255162167596, 'lr_C': 0.04007565017586694}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:34:55,580] Trial 40 finished with value: 0.7439779598205578 and parameters: {'age_weight': 1.8, 'n_estimators': 150, 'max_depth': 10, 'learning_rate': 0.013344949357389634, 'lr_C': 0.09130072836151248}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:37:09,459] Trial 41 finished with value: 0.7460600741174177 and parameters: {'age_weight': 1.1, 'n_estimators': 78, 'max_depth': 5, 'learning_rate': 0.020033435743369944, 'lr_C': 0.0036648443074630693}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:39:11,605] Trial 42 finished with value: 0.7462112346401405 and parameters: {'age_weight': 1.1, 'n_estimators': 69, 'max_depth': 5, 'learning_rate': 0.021012722246439755, 'lr_C': 0.005233069675681829}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:41:17,126] Trial 43 finished with value: 0.7444850789935635 and parameters: {'age_weight': 1.3, 'n_estimators': 56, 'max_depth': 6, 'learning_rate': 0.03272616876160652, 'lr_C': 0.018910797591651967}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:43:24,650] Trial 44 finished with value: 0.7446557440998635 and parameters: {'age_weight': 1.1, 'n_estimators': 70, 'max_depth': 7, 'learning_rate': 0.08305904367027939, 'lr_C': 0.0016634599791513188}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:45:17,264] Trial 45 finished with value: 0.745177491710552 and parameters: {'age_weight': 1.4, 'n_estimators': 64, 'max_depth': 8, 'learning_rate': 0.046023100233712214, 'lr_C': 0.008332621897437912}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:47:36,663] Trial 46 finished with value: 0.7447337624341721 and parameters: {'age_weight': 1.5, 'n_estimators': 119, 'max_depth': 5, 'learning_rate': 0.012446962361670285, 'lr_C': 0.0023470183909587838}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:50:04,178] Trial 47 finished with value: 0.7423444509459722 and parameters: {'age_weight': 2.8, 'n_estimators': 165, 'max_depth': 6, 'learning_rate': 0.017131751128530368, 'lr_C': 0.0010020195088954016}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:51:57,650] Trial 48 finished with value: 0.7447191339964891 and parameters: {'age_weight': 1.2, 'n_estimators': 90, 'max_depth': 3, 'learning_rate': 0.02265452289994455, 'lr_C': 0.012162974241202544}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:54:23,999] Trial 49 finished with value: 0.7447386385800663 and parameters: {'age_weight': 1.6, 'n_estimators': 103, 'max_depth': 9, 'learning_rate': 0.008139707101517782, 'lr_C': 0.019415877285708944}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:56:35,296] Trial 50 finished with value: 0.7460259410961576 and parameters: {'age_weight': 1.9, 'n_estimators': 55, 'max_depth': 4, 'learning_rate': 0.17769564387855238, 'lr_C': 0.004536851411568633}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 13:58:28,024] Trial 51 finished with value: 0.746084454846889 and parameters: {'age_weight': 1.1, 'n_estimators': 81, 'max_depth': 5, 'learning_rate': 0.024978747046487254, 'lr_C': 0.004474113473997633}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:00:36,370] Trial 52 finished with value: 0.7454456797347376 and parameters: {'age_weight': 1.0, 'n_estimators': 65, 'max_depth': 5, 'learning_rate': 0.04141740527149105, 'lr_C': 0.006994801241287334}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:02:52,690] Trial 53 finished with value: 0.745211624731812 and parameters: {'age_weight': 1.0, 'n_estimators': 71, 'max_depth': 7, 'learning_rate': 0.019503256786865826, 'lr_C': 0.009686461683782774}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:04:45,850] Trial 54 finished with value: 0.744884922956895 and parameters: {'age_weight': 1.1, 'n_estimators': 76, 'max_depth': 4, 'learning_rate': 0.030054859146777378, 'lr_C': 0.0025053710919590616}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:07:14,945] Trial 55 finished with value: 0.7424175931343865 and parameters: {'age_weight': 1.3, 'n_estimators': 95, 'max_depth': 6, 'learning_rate': 0.0010732035515582823, 'lr_C': 0.001631723668956235}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:09:25,092] Trial 56 finished with value: 0.7458260191144919 and parameters: {'age_weight': 1.2, 'n_estimators': 53, 'max_depth': 8, 'learning_rate': 0.01588206675388887, 'lr_C': 0.0035987393491047465}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:11:27,850] Trial 57 finished with value: 0.7441047396138093 and parameters: {'age_weight': 2.2, 'n_estimators': 80, 'max_depth': 5, 'learning_rate': 0.05009804100981513, 'lr_C': 0.02566419486647521}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:13:32,603] Trial 58 finished with value: 0.7452701384825434 and parameters: {'age_weight': 2.9000000000000004, 'n_estimators': 59, 'max_depth': 6, 'learning_rate': 0.004066812778398547, 'lr_C': 0.014991254738174708}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:15:51,791] Trial 59 finished with value: 0.7460747025551004 and parameters: {'age_weight': 2.6, 'n_estimators': 72, 'max_depth': 4, 'learning_rate': 0.02533815055722837, 'lr_C': 0.005462350652216664}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:18:05,475] Trial 60 finished with value: 0.7441291203432807 and parameters: {'age_weight': 1.4, 'n_estimators': 90, 'max_depth': 7, 'learning_rate': 0.2482133107851036, 'lr_C': 0.001353646217219358}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:20:04,051] Trial 61 finished with value: 0.7461673493270918 and parameters: {'age_weight': 1.1, 'n_estimators': 81, 'max_depth': 5, 'learning_rate': 0.022448401353501953, 'lr_C': 0.003753680554840122}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:22:03,137] Trial 62 finished with value: 0.7446703725375463 and parameters: {'age_weight': 1.1, 'n_estimators': 67, 'max_depth': 5, 'learning_rate': 0.021165674372471736, 'lr_C': 0.0023308638137343788}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:24:27,705] Trial 63 finished with value: 0.7460015603666862 and parameters: {'age_weight': 1.0, 'n_estimators': 83, 'max_depth': 5, 'learning_rate': 0.029450526312705026, 'lr_C': 0.0033079229799268333}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:26:40,907] Trial 64 finished with value: 0.7432709186658865 and parameters: {'age_weight': 1.3, 'n_estimators': 51, 'max_depth': 6, 'learning_rate': 0.011575374383868037, 'lr_C': 11.86437283650666}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:28:43,232] Trial 65 finished with value: 0.7449336844158376 and parameters: {'age_weight': 1.1, 'n_estimators': 62, 'max_depth': 4, 'learning_rate': 0.03667360928662676, 'lr_C': 0.00978071005222653}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:30:54,985] Trial 66 finished with value: 0.7462599960990832 and parameters: {'age_weight': 1.2, 'n_estimators': 103, 'max_depth': 5, 'learning_rate': 0.015224803169748473, 'lr_C': 0.005577562020168078}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:32:52,634] Trial 67 finished with value: 0.7462307392237175 and parameters: {'age_weight': 1.7000000000000002, 'n_estimators': 105, 'max_depth': 5, 'learning_rate': 0.008231331611722788, 'lr_C': 0.005755166888082023}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:35:14,691] Trial 68 finished with value: 0.7460454456797347 and parameters: {'age_weight': 1.7000000000000002, 'n_estimators': 105, 'max_depth': 6, 'learning_rate': 0.005412543638985296, 'lr_C': 0.006548332574870758}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:37:33,579] Trial 69 finished with value: 0.7439828359664521 and parameters: {'age_weight': 1.5, 'n_estimators': 116, 'max_depth': 4, 'learning_rate': 0.008799306966891554, 'lr_C': 0.031146598452168207}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:39:56,447] Trial 70 finished with value: 0.7442754047201092 and parameters: {'age_weight': 1.6, 'n_estimators': 122, 'max_depth': 5, 'learning_rate': 0.007142648054299809, 'lr_C': 0.0023690804861490663}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:41:49,088] Trial 71 finished with value: 0.746186853910669 and parameters: {'age_weight': 1.8, 'n_estimators': 98, 'max_depth': 5, 'learning_rate': 0.009927848010066501, 'lr_C': 0.00489483508092}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:43:56,544] Trial 72 finished with value: 0.7461917300565633 and parameters: {'age_weight': 1.9, 'n_estimators': 108, 'max_depth': 5, 'learning_rate': 0.005171418363640824, 'lr_C': 0.005833252032753289}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:46:24,665] Trial 73 finished with value: 0.7420518821923152 and parameters: {'age_weight': 1.9, 'n_estimators': 108, 'max_depth': 5, 'learning_rate': 0.0026487729577266213, 'lr_C': 0.0013133760466673566}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:48:37,350] Trial 74 finished with value: 0.745231129315389 and parameters: {'age_weight': 2.0, 'n_estimators': 112, 'max_depth': 6, 'learning_rate': 0.014010532773265173, 'lr_C': 0.01110847536245363}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:50:53,844] Trial 75 finished with value: 0.7457723815096549 and parameters: {'age_weight': 2.1, 'n_estimators': 94, 'max_depth': 5, 'learning_rate': 0.016169252308239023, 'lr_C': 0.007249970369292713}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:52:58,644] Trial 76 finished with value: 0.744992198166569 and parameters: {'age_weight': 1.8, 'n_estimators': 125, 'max_depth': 3, 'learning_rate': 0.004766617333815058, 'lr_C': 0.01449156822913447}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:55:15,471] Trial 77 finished with value: 0.7462453676614004 and parameters: {'age_weight': 1.7000000000000002, 'n_estimators': 101, 'max_depth': 6, 'learning_rate': 0.08936665502376524, 'lr_C': 0.0031257877877109304}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:57:09,646] Trial 78 finished with value: 0.7454261751511606 and parameters: {'age_weight': 1.6, 'n_estimators': 134, 'max_depth': 6, 'learning_rate': 0.14756502206156502, 'lr_C': 0.002053982036582752}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 14:59:23,520] Trial 79 finished with value: 0.7439682075287692 and parameters: {'age_weight': 1.7000000000000002, 'n_estimators': 99, 'max_depth': 7, 'learning_rate': 0.08794986521171934, 'lr_C': 0.43733531454321384}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:01:52,312] Trial 80 finished with value: 0.745211624731812 and parameters: {'age_weight': 1.5, 'n_estimators': 192, 'max_depth': 8, 'learning_rate': 0.12518523572902943, 'lr_C': 0.0030578712067417745}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:03:58,796] Trial 81 finished with value: 0.745587087965672 and parameters: {'age_weight': 1.7000000000000002, 'n_estimators': 102, 'max_depth': 5, 'learning_rate': 0.054812911403830704, 'lr_C': 0.006305103613375134}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:05:53,943] Trial 82 finished with value: 0.7461234640140433 and parameters: {'age_weight': 1.9, 'n_estimators': 110, 'max_depth': 5, 'learning_rate': 0.06916854605391187, 'lr_C': 0.00292590657064354}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:07:41,684] Trial 83 finished with value: 0.7461039594304661 and parameters: {'age_weight': 2.0, 'n_estimators': 114, 'max_depth': 6, 'learning_rate': 0.10007918504575006, 'lr_C': 0.004852212836453214}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:09:44,963] Trial 84 finished with value: 0.7459918080748976 and parameters: {'age_weight': 1.6, 'n_estimators': 106, 'max_depth': 5, 'learning_rate': 0.0034899816052001062, 'lr_C': 0.008065524464935275}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:11:56,108] Trial 85 finished with value: 0.7452067485859176 and parameters: {'age_weight': 1.8, 'n_estimators': 86, 'max_depth': 9, 'learning_rate': 0.21195853115818147, 'lr_C': 0.003923282414641699}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:14:03,419] Trial 86 finished with value: 0.7421689096937781 and parameters: {'age_weight': 1.4, 'n_estimators': 92, 'max_depth': 4, 'learning_rate': 0.005675643947397235, 'lr_C': 0.0013772398324002916}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:16:02,297] Trial 87 finished with value: 0.7431002535595865 and parameters: {'age_weight': 1.3, 'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.018351334502647344, 'lr_C': 1.219497295397365}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:17:56,057] Trial 88 finished with value: 0.7456114686951433 and parameters: {'age_weight': 1.5, 'n_estimators': 89, 'max_depth': 6, 'learning_rate': 0.007128821111779422, 'lr_C': 0.0107278523346964}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:19:56,684] Trial 89 finished with value: 0.7451384825433977 and parameters: {'age_weight': 1.9, 'n_estimators': 58, 'max_depth': 5, 'learning_rate': 0.012667667581951836, 'lr_C': 0.01723560962425144}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:21:55,070] Trial 90 finished with value: 0.7445826019114492 and parameters: {'age_weight': 1.7000000000000002, 'n_estimators': 74, 'max_depth': 7, 'learning_rate': 0.0024287522762311904, 'lr_C': 0.12963708446978744}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:24:01,466] Trial 91 finished with value: 0.7462014823483518 and parameters: {'age_weight': 1.8, 'n_estimators': 99, 'max_depth': 5, 'learning_rate': 0.010663842764926334, 'lr_C': 0.005198637827385579}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:25:56,356] Trial 92 finished with value: 0.746152720889409 and parameters: {'age_weight': 2.0, 'n_estimators': 96, 'max_depth': 5, 'learning_rate': 0.010702693241857575, 'lr_C': 0.0056029944237858354}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:27:52,655] Trial 93 finished with value: 0.7439048176321436 and parameters: {'age_weight': 1.8, 'n_estimators': 106, 'max_depth': 5, 'learning_rate': 0.00914920661663632, 'lr_C': 0.0020090218307419203}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:30:07,632] Trial 94 finished with value: 0.7458845328652235 and parameters: {'age_weight': 1.7000000000000002, 'n_estimators': 101, 'max_depth': 8, 'learning_rate': 0.015493534416105922, 'lr_C': 0.003076831617598245}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:32:22,714] Trial 95 finished with value: 0.7456846108835576 and parameters: {'age_weight': 1.9, 'n_estimators': 94, 'max_depth': 4, 'learning_rate': 0.11844959793350786, 'lr_C': 0.008097264983740554}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:34:11,834] Trial 96 finished with value: 0.7457577530719719 and parameters: {'age_weight': 1.6, 'n_estimators': 53, 'max_depth': 6, 'learning_rate': 0.14408074361759401, 'lr_C': 0.004429785007207727}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:36:06,226] Trial 97 finished with value: 0.7440706065925492 and parameters: {'age_weight': 2.4000000000000004, 'n_estimators': 86, 'max_depth': 5, 'learning_rate': 0.04113018068653983, 'lr_C': 0.02501377482848303}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:37:52,826] Trial 98 finished with value: 0.7456699824458749 and parameters: {'age_weight': 1.2, 'n_estimators': 117, 'max_depth': 4, 'learning_rate': 0.0047586313774222, 'lr_C': 0.009100699101913811}. Best is trial 21 with value: 0.7462941291203433.
# [I 2025-02-23 15:39:59,479] Trial 99 finished with value: 0.7461575970353033 and parameters: {'age_weight': 2.1, 'n_estimators': 68, 'max_depth': 6, 'learning_rate': 0.007301651439964411, 'lr_C': 0.005902415369247504}. Best is trial 21 with value: 0.7462941291203433.

# %%
import joblib
# 저장된 모델 불러오기
final_model = joblib.load('./LightGBM_boosting2.pkl')

# 추가 학습을 위해 warm_start 활성화
final_model.warm_start = True
final_model.n_estimators += 50  # 추가 부스팅 라운드 개수 설정

# 추가 학습 진행 (적절한 X_train, y_train 데이터를 사용)
final_model.fit(X_train_encoded, y)
# Out:
# LGBMClassifier(colsample_bytree=0.6283518615400887,
#                learning_rate=0.020414102740183366, max_depth=9,
#                min_child_samples=14, n_estimators=1070, num_leaves=35,
#                reg_alpha=9.422816220857865, reg_lambda=3.965116334727029e-05,
#                subsample=0.8361505791254964)

# %%
# 최적의 하이퍼파라미터로 최종 모델 구성 및 평가
best_params = study.best_trial.params

# 사전에 저장된 LightGBM 모델 불러오기 (변경 없음)
pre_trained_lgb = joblib.load('./LightGBM_boosting2.pkl')

# 최적화된 XGBoost 모델
best_xgb = XGBClassifier(**best_params,
                         random_state=42,
                         use_label_encoder=False,
                         eval_metric='logloss')

# 최적화된 메타 모델 (로지스틱 회귀)
best_meta = LogisticRegression(C=best_params['lr_C'], random_state=42, max_iter=1000)

# 최종 스태킹 모델 구성
final_stack_model = StackingClassifier(estimators=[('lgb', pre_trained_lgb), ('xgb', best_xgb)],
                                         final_estimator=best_meta,
                                         cv=5)

# %%
# 최종 모델 학습 및 평가
final_stack_model.fit(X_train_encoded, y)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 66228, number of negative: 190123
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011710 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 716
# [LightGBM] [Info] Number of data points in the train set: 256351, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258349 -> initscore=-1.054568
# [LightGBM] [Info] Start training from score -1.054568
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008558 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 715
# [LightGBM] [Info] Number of data points in the train set: 205080, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010351 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 716
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010636 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 712
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009365 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 715
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007655 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 715
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# StackingClassifier(cv=5,
#                    estimators=[('lgb',
#                                 LGBMClassifier(colsample_bytree=0.6283518615400887,
#                                                learning_rate=0.020414102740183366,
#                                                max_depth=9,
#                                                min_child_samples=14,
#                                                n_estimators=1020, num_leaves=35,
#                                                reg_alpha=9.422816220857865,
#                                                reg_lambda=3.965116334727029e-05,
#                                                subsample=0.8361505791254964)),
#                                ('xgb',
#                                 XGBClassifier(age_weight=1.5, base_score=None,
#                                               booster=None...
#                                               learning_rate=0.12891682151367456,
#                                               lr_C=0.0034113886132639726,
#                                               max_bin=None,
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None, max_depth=5,
#                                               max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=55, n_jobs=None, ...))],
#                    final_estimator=LogisticRegression(C=0.0034113886132639726,
#                                                       max_iter=1000,
#                                                       random_state=42))

# %%
from sklearn.metrics import accuracy_score, roc_auc_score

# 예측
y_train_pred = final_stack_model.predict(X_train_encoded)
y_train_proba = final_stack_model.predict_proba(X_train_encoded)[:, 1]  # ROC-AUC Score 계산용

# 평가
accuracy = accuracy_score(y, y_train_pred)
roc_auc = roc_auc_score(y, y_train_proba)

# 출력
print(f"Accuracy: {accuracy:.4f}")
print(f"ROC-AUC Score: {roc_auc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 from sklearn.metrics import accuracy_score, roc_auc_score
#       3 # 예측
# ----> 4 y_train_pred = final_stack_model.predict(X_train_encoded)
#       5 y_train_proba = final_stack_model.predict_proba(X_train_encoded)[:, 1]  # ROC-AUC Score 계산용
#       7 # 평가
#
# NameError: name 'final_stack_model' is not defined

# %%
from sklearn.metrics import accuracy_score, roc_auc_score

# 예측
y_train_pred = stacking_clf.predict(X_train_encoded)
y_train_proba = stacking_clf.predict_proba(X_train_encoded)[:, 1]  # ROC-AUC Score 계산용

# 평가
accuracy = accuracy_score(y, y_train_pred)
roc_auc = roc_auc_score(y, y_train_proba)

# 출력
print(f"Accuracy: {accuracy:.4f}")
print(f"ROC-AUC Score: {roc_auc:.4f}")
# Out:
# c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] 지정된 파일을 찾을 수 없습니다
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "c:\Users\vhehr\.conda\envs\LGAimers6\Lib\subprocess.py", line 556, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\vhehr\.conda\envs\LGAimers6\Lib\subprocess.py", line 1038, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\vhehr\.conda\envs\LGAimers6\Lib\subprocess.py", line 1550, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^
# Accuracy: 0.7636
# ROC-AUC Score: 0.7783

# %%
import joblib

# Optuna 최적화 실행 후 최적의 study 저장
joblib.dump(stacking_clf, "stacking(LightGBM+xgboost+ExtraTrees).pkl")
# Out:
# ['stacking(LightGBM+xgboost+ExtraTrees).pkl']

# %% [markdown]
# ### Predict

# %%
pred_proba = stacking_clf.predict_proba(X_test_encoded)[:, 1]

# %% [markdown]
# ### Submission

# %%
sample_submission = pd.read_csv('./Data/sample_submission.csv')
sample_submission['probability'] = pred_proba

# %%
sample_submission.to_csv('./stacking(LightGBM+xgboost+ExtraTrees)_submit.csv', index=False)
