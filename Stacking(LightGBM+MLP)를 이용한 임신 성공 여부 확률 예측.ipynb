# %% [markdown]
# ### Import

# %%
# !conda install lightgbm
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - lightgbm-gpu
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge
#   - https://repo.anaconda.com/pkgs/main
#   - https://repo.anaconda.com/pkgs/r
#   - https://repo.anaconda.com/pkgs/msys2
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import pandas as pd
import numpy as np

from sklearn.preprocessing import OrdinalEncoder

import optuna
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.metrics import roc_auc_score, make_scorer

# %%
# GPU 장치 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device:", device)
# Out:
# False
# Using device: cpu

# %% [markdown]
# ### Data Load

# %%
train = pd.read_csv('./Data/train.csv').drop(columns=['ID'])
test = pd.read_csv('./Data/test.csv').drop(columns=['ID'])

# %%
X = train.drop('임신 성공 여부', axis=1)
y = train['임신 성공 여부']

# %% [markdown]
# ### Data Pre-processing

# %%
categorical_columns = [
    "시술 시기 코드",
    "시술 당시 나이",
    "시술 유형",
    "특정 시술 유형",
    "배란 자극 여부",
    "배란 유도 유형",
    "단일 배아 이식 여부",
    "착상 전 유전 검사 사용 여부",
    "착상 전 유전 진단 사용 여부",
    "남성 주 불임 원인",
    "남성 부 불임 원인",
    "여성 주 불임 원인",
    "여성 부 불임 원인",
    "부부 주 불임 원인",
    "부부 부 불임 원인",
    "불명확 불임 원인",
    "불임 원인 - 난관 질환",
    "불임 원인 - 남성 요인",
    "불임 원인 - 배란 장애",
    "불임 원인 - 여성 요인",
    "불임 원인 - 자궁경부 문제",
    "불임 원인 - 자궁내막증",
    "불임 원인 - 정자 농도",
    "불임 원인 - 정자 면역학적 요인",
    "불임 원인 - 정자 운동성",
    "불임 원인 - 정자 형태",
    "배아 생성 주요 이유",
    "총 시술 횟수",
    "클리닉 내 총 시술 횟수",
    "IVF 시술 횟수",
    "DI 시술 횟수",
    "총 임신 횟수",
    "IVF 임신 횟수",
    "DI 임신 횟수",
    "총 출산 횟수",
    "IVF 출산 횟수",
    "DI 출산 횟수",
    "난자 출처",
    "정자 출처",
    "난자 기증자 나이",
    "정자 기증자 나이",
    "동결 배아 사용 여부",
    "신선 배아 사용 여부",
    "기증 배아 사용 여부",
    "대리모 여부",
    "PGD 시술 여부",
    "PGS 시술 여부"
]

# %%
# 카테고리형 컬럼들을 문자열로 변환
for col in categorical_columns:
    X[col] = X[col].astype(str)
    test[col] = test[col].astype(str)

# %%
ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

X_train_encoded = X.copy()
X_train_encoded[categorical_columns] = ordinal_encoder.fit_transform(X[categorical_columns])

X_test_encoded = test.copy()
X_test_encoded[categorical_columns] = ordinal_encoder.transform(test[categorical_columns])

# %%
numeric_columns = [
    "임신 시도 또는 마지막 임신 경과 연수",
    "총 생성 배아 수",
    "미세주입된 난자 수",
    "미세주입에서 생성된 배아 수",
    "이식된 배아 수",
    "미세주입 배아 이식 수",
    "저장된 배아 수",
    "미세주입 후 저장된 배아 수",
    "해동된 배아 수",
    "해동 난자 수",
    "수집된 신선 난자 수",
    "저장된 신선 난자 수",
    "혼합된 난자 수",
    "파트너 정자와 혼합된 난자 수",
    "기증자 정자와 혼합된 난자 수",
    "난자 채취 경과일",
    "난자 해동 경과일",
    "난자 혼합 경과일",
    "배아 이식 경과일",
    "배아 해동 경과일"
]

# %%
numeric_columns = [col for col in numeric_columns if col in X.columns]

X_train_encoded[numeric_columns] = X_train_encoded[numeric_columns].fillna(0)
X_test_encoded[numeric_columns] = X_test_encoded[numeric_columns].fillna(0)

# %%
from collections import Counter

# 클래스별 샘플 개수 출력
class_counts = Counter(y)
print(class_counts)
# Out:
# Counter({0: 190123, 1: 66228})

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_train_encoded, y, test_size=0.2, random_state=42, stratify=y
)

# %% [markdown]
# ### Train

# %% [markdown]
# Lightgbm

# %%
import joblib

def objective(trial):
    # 사전에 저장된 LightGBM 모델 불러오기 (이미 학습된 모델)
    pre_trained_lgb = joblib.load('./LightGBM_boosting2.pkl')
    
    age_weight = trial.suggest_float("age_weight", 1.0, 3.0, step=0.1)
    X_train_weighted = X_train_encoded.copy()
    
    # '시술 당시 나이' 컬럼에만 가중치 부여
    if '시술 당시 나이' in X_train_encoded.columns:
        X_train_weighted['시술 당시 나이'] *= age_weight
        
    # MLP 하이퍼파라미터 튜닝
    mlp_params= {
        'hidden_layer_sizes' : trial.suggest_int("mlp_hidden_layer_sizes", 50, 300),
        'alpha' : trial.suggest_float("mlp_alpha", 0.0001, 0.1, log=True),
        'learning_rate_init' : trial.suggest_float("mlp_learning_rate_init", 0.001, 0.1, log=True)
    }
    mlp_model = MLPClassifier(**mlp_params, max_iter=1000, random_state=42)
    
    # 베이스 모델 정의
    base_models = [
        ('lgbm', pre_trained_lgb),
        ('mlp', mlp_model)
    ]

    # 메타 모델 (로지스틱 회귀) 하이퍼파라미터 최적화
    lr_C = trial.suggest_loguniform('lr_C', 1e-3, 1e2)
    meta_model = LogisticRegression(C=lr_C, random_state=42, max_iter=1000)
    
    # 스태킹 모델 구성
    stacking_clf = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=StratifiedKFold(n_splits=3))

    # AUC 기반 교차 검증 수행
    auc_scores = cross_val_score(stacking_clf, X_train_weighted, y, cv=StratifiedKFold(n_splits=3), scoring='roc_auc', n_jobs=-1)
    
    return np.mean(auc_scores)

# %%
import warnings

# 불필요한 경고 제거
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.filterwarnings("ignore", category=UserWarning, module="lightbgm")

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=150, show_progress_bar=True)
# Out:
# [I 2025-02-25 18:19:57,711] A new study created in memory with name: no-name-d889adc0-180d-4ef0-84a4-010dcddac43f
#   0%|          | 0/150 [00:00<?, ?it/s]
# [I 2025-02-25 18:22:42,360] Trial 0 finished with value: 0.7395775104128545 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 51, 'mlp_alpha': 0.00031775895543037063, 'mlp_learning_rate_init': 0.0012982924503154708, 'lr_C': 0.5407452339042454}. Best is trial 0 with value: 0.7395775104128545.
# [I 2025-02-25 18:23:51,391] Trial 1 finished with value: 0.7384386921779754 and parameters: {'age_weight': 2.8, 'mlp_hidden_layer_sizes': 240, 'mlp_alpha': 0.000389820683265132, 'mlp_learning_rate_init': 0.04834413867331109, 'lr_C': 0.060718264385518264}. Best is trial 0 with value: 0.7395775104128545.
# [I 2025-02-25 18:25:03,966] Trial 2 finished with value: 0.7388750809681669 and parameters: {'age_weight': 2.3, 'mlp_hidden_layer_sizes': 123, 'mlp_alpha': 0.016058586162497283, 'mlp_learning_rate_init': 0.020257025123775283, 'lr_C': 0.09383578112539094}. Best is trial 0 with value: 0.7395775104128545.
# [I 2025-02-25 18:26:07,216] Trial 3 finished with value: 0.7381498011224727 and parameters: {'age_weight': 1.4, 'mlp_hidden_layer_sizes': 179, 'mlp_alpha': 0.006929647177765867, 'mlp_learning_rate_init': 0.0715650610838686, 'lr_C': 0.005862213267969104}. Best is trial 0 with value: 0.7395775104128545.
# [I 2025-02-25 18:26:59,827] Trial 4 finished with value: 0.7385031436327706 and parameters: {'age_weight': 1.0, 'mlp_hidden_layer_sizes': 64, 'mlp_alpha': 0.026153682583456222, 'mlp_learning_rate_init': 0.024308725850358464, 'lr_C': 0.1424702286522328}. Best is trial 0 with value: 0.7395775104128545.
# [I 2025-02-25 18:28:42,087] Trial 5 finished with value: 0.7385106466816485 and parameters: {'age_weight': 2.7, 'mlp_hidden_layer_sizes': 270, 'mlp_alpha': 0.00010813943411275997, 'mlp_learning_rate_init': 0.01598956734834528, 'lr_C': 0.0029753005794643716}. Best is trial 0 with value: 0.7395775104128545.
# [I 2025-02-25 18:30:02,764] Trial 6 finished with value: 0.7368793448338149 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 294, 'mlp_alpha': 0.00011286249727637851, 'mlp_learning_rate_init': 0.08488896291265566, 'lr_C': 19.32269703380112}. Best is trial 0 with value: 0.7395775104128545.
# [I 2025-02-25 18:32:04,587] Trial 7 finished with value: 0.7386642964543005 and parameters: {'age_weight': 1.2, 'mlp_hidden_layer_sizes': 285, 'mlp_alpha': 0.005903692319655335, 'mlp_learning_rate_init': 0.007918354703535704, 'lr_C': 8.841927367024766}. Best is trial 0 with value: 0.7395775104128545.
# [I 2025-02-25 18:34:41,407] Trial 8 finished with value: 0.7394049862030059 and parameters: {'age_weight': 2.4000000000000004, 'mlp_hidden_layer_sizes': 203, 'mlp_alpha': 0.019078735428465565, 'mlp_learning_rate_init': 0.0011222175904838962, 'lr_C': 0.008234115466442269}. Best is trial 0 with value: 0.7395775104128545.
# [I 2025-02-25 18:37:20,312] Trial 9 finished with value: 0.739537492766312 and parameters: {'age_weight': 1.3, 'mlp_hidden_layer_sizes': 142, 'mlp_alpha': 0.001015901955038977, 'mlp_learning_rate_init': 0.0029301020454555703, 'lr_C': 0.0478425563234283}. Best is trial 0 with value: 0.7395775104128545.
# [I 2025-02-25 18:39:56,069] Trial 10 finished with value: 0.7396122156970298 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 55, 'mlp_alpha': 0.0011623337892759818, 'mlp_learning_rate_init': 0.00111823849454717, 'lr_C': 2.093400980019249}. Best is trial 10 with value: 0.7396122156970298.
# [I 2025-02-25 18:42:51,861] Trial 11 finished with value: 0.7394509670841002 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 67, 'mlp_alpha': 0.0010679037121454466, 'mlp_learning_rate_init': 0.0010339402595163948, 'lr_C': 2.0929085831096934}. Best is trial 10 with value: 0.7396122156970298.
# [I 2025-02-25 18:44:46,187] Trial 12 finished with value: 0.7394493057551386 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 100, 'mlp_alpha': 0.0011455960755271267, 'mlp_learning_rate_init': 0.0030258455140190345, 'lr_C': 0.7564443753001372}. Best is trial 10 with value: 0.7396122156970298.
# [I 2025-02-25 18:46:29,661] Trial 13 finished with value: 0.7396861482899751 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 54, 'mlp_alpha': 0.000429561388071362, 'mlp_learning_rate_init': 0.0028213457318961442, 'lr_C': 2.349620510821637}. Best is trial 13 with value: 0.7396861482899751.
# [I 2025-02-25 18:48:04,838] Trial 14 finished with value: 0.7396573806387049 and parameters: {'age_weight': 2.2, 'mlp_hidden_layer_sizes': 102, 'mlp_alpha': 0.0018047159577874925, 'mlp_learning_rate_init': 0.002767647266687217, 'lr_C': 98.78597636572522}. Best is trial 13 with value: 0.7396861482899751.
# [I 2025-02-25 18:49:26,397] Trial 15 finished with value: 0.7390923631685175 and parameters: {'age_weight': 2.2, 'mlp_hidden_layer_sizes': 98, 'mlp_alpha': 0.0021925037564151993, 'mlp_learning_rate_init': 0.004422178787596455, 'lr_C': 45.55422320008697}. Best is trial 13 with value: 0.7396861482899751.
# [I 2025-02-25 18:50:36,427] Trial 16 finished with value: 0.7390386462766902 and parameters: {'age_weight': 2.6, 'mlp_hidden_layer_sizes': 100, 'mlp_alpha': 0.0655071074492877, 'mlp_learning_rate_init': 0.006135408816567724, 'lr_C': 69.52416965515417}. Best is trial 13 with value: 0.7396861482899751.
# [I 2025-02-25 18:54:18,740] Trial 17 finished with value: 0.7394419942974642 and parameters: {'age_weight': 3.0, 'mlp_hidden_layer_sizes': 166, 'mlp_alpha': 0.0002586207141535452, 'mlp_learning_rate_init': 0.002185978037735921, 'lr_C': 8.808065366917313}. Best is trial 13 with value: 0.7396861482899751.
# [I 2025-02-25 18:55:25,317] Trial 18 finished with value: 0.7386901182204553 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 135, 'mlp_alpha': 0.0030915119551175865, 'mlp_learning_rate_init': 0.011680945077453138, 'lr_C': 2.4463539498635165}. Best is trial 13 with value: 0.7396861482899751.
# [I 2025-02-25 18:57:52,951] Trial 19 finished with value: 0.739549733829698 and parameters: {'age_weight': 2.5, 'mlp_hidden_layer_sizes': 86, 'mlp_alpha': 0.0005161378039508166, 'mlp_learning_rate_init': 0.0021262301883376404, 'lr_C': 13.26962669602839}. Best is trial 13 with value: 0.7396861482899751.
# [I 2025-02-25 18:59:10,601] Trial 20 finished with value: 0.7392806048612807 and parameters: {'age_weight': 1.5, 'mlp_hidden_layer_sizes': 121, 'mlp_alpha': 0.005685313955123515, 'mlp_learning_rate_init': 0.004353894190170002, 'lr_C': 25.71532328436086}. Best is trial 13 with value: 0.7396861482899751.
# [I 2025-02-25 19:00:55,934] Trial 21 finished with value: 0.7396786128484889 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 50, 'mlp_alpha': 0.0018070336298334295, 'mlp_learning_rate_init': 0.0018311241994933933, 'lr_C': 1.453278213783528}. Best is trial 13 with value: 0.7396861482899751.
# [I 2025-02-25 19:02:31,037] Trial 22 finished with value: 0.73972242593842 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 75, 'mlp_alpha': 0.002070520231462415, 'mlp_learning_rate_init': 0.0026324308644721803, 'lr_C': 3.6711540592488707}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:05:09,109] Trial 23 finished with value: 0.7394070635391387 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 76, 'mlp_alpha': 0.0007451898670444926, 'mlp_learning_rate_init': 0.0017040800881122796, 'lr_C': 3.791442468458843}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:06:41,673] Trial 24 finished with value: 0.7395095916451071 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 84, 'mlp_alpha': 0.00022376618513136765, 'mlp_learning_rate_init': 0.004602514295165264, 'lr_C': 0.2955553300585031}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:08:47,589] Trial 25 finished with value: 0.7396717857123999 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 71, 'mlp_alpha': 0.002758787243311539, 'mlp_learning_rate_init': 0.0018424888230210198, 'lr_C': 0.8724272730392547}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:10:08,825] Trial 26 finished with value: 0.739620427859128 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 56, 'mlp_alpha': 0.0005872853080085541, 'mlp_learning_rate_init': 0.006122069700262598, 'lr_C': 3.750709842269018}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:11:39,537] Trial 27 finished with value: 0.7392556067580758 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 156, 'mlp_alpha': 0.009477653936627193, 'mlp_learning_rate_init': 0.003308808736433355, 'lr_C': 0.26124366915485664}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:15:32,688] Trial 28 finished with value: 0.739603028406305 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 206, 'mlp_alpha': 0.0017229535972738106, 'mlp_learning_rate_init': 0.0015795280553120524, 'lr_C': 1.221583010626612}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:18:08,456] Trial 29 finished with value: 0.7394077237326288 and parameters: {'age_weight': 2.4000000000000004, 'mlp_hidden_layer_sizes': 54, 'mlp_alpha': 0.00017969281968537623, 'mlp_learning_rate_init': 0.0015113750196444592, 'lr_C': 0.5035156612952787}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:19:21,343] Trial 30 finished with value: 0.738897133068507 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 117, 'mlp_alpha': 0.004498710519902686, 'mlp_learning_rate_init': 0.010781876946243014, 'lr_C': 0.02269123280065033}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:20:57,076] Trial 31 finished with value: 0.7397148204427011 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 78, 'mlp_alpha': 0.0030881820570046563, 'mlp_learning_rate_init': 0.0021411385450810674, 'lr_C': 0.9920588588274303}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:23:14,091] Trial 32 finished with value: 0.739460364378008 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 85, 'mlp_alpha': 0.0003690569364630071, 'mlp_learning_rate_init': 0.0025113124248293916, 'lr_C': 7.184439924857456}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:24:27,402] Trial 33 finished with value: 0.7395074906539257 and parameters: {'age_weight': 2.2, 'mlp_hidden_layer_sizes': 54, 'mlp_alpha': 0.003802262524482324, 'mlp_learning_rate_init': 0.003946680265670684, 'lr_C': 1.3747140879766913}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:25:20,556] Trial 34 finished with value: 0.738771449685392 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 76, 'mlp_alpha': 0.010757802862664756, 'mlp_learning_rate_init': 0.033419899766100505, 'lr_C': 0.5020911332037163}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:28:31,947] Trial 35 finished with value: 0.7395221391199837 and parameters: {'age_weight': 2.3, 'mlp_hidden_layer_sizes': 111, 'mlp_alpha': 0.0016761357546980424, 'mlp_learning_rate_init': 0.0013996101175141654, 'lr_C': 4.811957325378247}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:30:01,074] Trial 36 finished with value: 0.7392320172211214 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 88, 'mlp_alpha': 0.00047852267827726015, 'mlp_learning_rate_init': 0.006000938515150856, 'lr_C': 0.0010018806862737459}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:31:52,004] Trial 37 finished with value: 0.7396072682233322 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 66, 'mlp_alpha': 0.0008002788353633219, 'mlp_learning_rate_init': 0.0024651624625145157, 'lr_C': 0.15313935699317938}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:33:09,716] Trial 38 finished with value: 0.7394734146982888 and parameters: {'age_weight': 1.5, 'mlp_hidden_layer_sizes': 52, 'mlp_alpha': 0.008757247088120689, 'mlp_learning_rate_init': 0.0019774258369382983, 'lr_C': 1.3647608938345315}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:35:22,982] Trial 39 finished with value: 0.7395089612045597 and parameters: {'age_weight': 2.4000000000000004, 'mlp_hidden_layer_sizes': 236, 'mlp_alpha': 0.0027443328279274566, 'mlp_learning_rate_init': 0.0034861232168342023, 'lr_C': 0.19192921899848284}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:36:50,698] Trial 40 finished with value: 0.7391162972260208 and parameters: {'age_weight': 1.1, 'mlp_hidden_layer_sizes': 129, 'mlp_alpha': 0.004702754637279626, 'mlp_learning_rate_init': 0.008182109189621936, 'lr_C': 22.253340090125764}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:38:40,000] Trial 41 finished with value: 0.7396959827557431 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 74, 'mlp_alpha': 0.002487793217978133, 'mlp_learning_rate_init': 0.0019565176919014273, 'lr_C': 0.7644904382631282}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:40:41,234] Trial 42 finished with value: 0.7394848509449893 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 69, 'mlp_alpha': 0.002281617900852045, 'mlp_learning_rate_init': 0.001800659084695745, 'lr_C': 0.06852670638090184}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:43:15,393] Trial 43 finished with value: 0.7394591206563025 and parameters: {'age_weight': 2.3, 'mlp_hidden_layer_sizes': 77, 'mlp_alpha': 0.001541407599524854, 'mlp_learning_rate_init': 0.0012032740954976222, 'lr_C': 2.5637476036063873}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:45:44,028] Trial 44 finished with value: 0.7395589134704527 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 92, 'mlp_alpha': 0.003611761500608825, 'mlp_learning_rate_init': 0.0012961465147378495, 'lr_C': 0.46905140152171815}. Best is trial 22 with value: 0.73972242593842.
# [I 2025-02-25 19:47:12,499] Trial 45 finished with value: 0.7397265183903373 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 108, 'mlp_alpha': 0.01582885442122256, 'mlp_learning_rate_init': 0.002416355441596722, 'lr_C': 0.7469465488836381}. Best is trial 45 with value: 0.7397265183903373.
# [I 2025-02-25 19:48:42,111] Trial 46 finished with value: 0.7396313276597729 and parameters: {'age_weight': 1.4, 'mlp_hidden_layer_sizes': 112, 'mlp_alpha': 0.01295776806758423, 'mlp_learning_rate_init': 0.0024614158663682625, 'lr_C': 0.6908091438867582}. Best is trial 45 with value: 0.7397265183903373.
# [I 2025-02-25 19:50:13,681] Trial 47 finished with value: 0.7392309799194182 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 145, 'mlp_alpha': 0.007105159009317072, 'mlp_learning_rate_init': 0.0054666852442703, 'lr_C': 6.0884835401743524}. Best is trial 45 with value: 0.7397265183903373.
# [I 2025-02-25 19:51:29,003] Trial 48 finished with value: 0.7388877945961402 and parameters: {'age_weight': 1.3, 'mlp_hidden_layer_sizes': 107, 'mlp_alpha': 0.024394945899493915, 'mlp_learning_rate_init': 0.015553142205379558, 'lr_C': 0.9595320308470168}. Best is trial 45 with value: 0.7397265183903373.
# [I 2025-02-25 19:53:15,751] Trial 49 finished with value: 0.7391959087838013 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 186, 'mlp_alpha': 0.040621460325973385, 'mlp_learning_rate_init': 0.003738736247225451, 'lr_C': 0.0834527848719738}. Best is trial 45 with value: 0.7397265183903373.
# [I 2025-02-25 19:54:36,064] Trial 50 finished with value: 0.7394856194498982 and parameters: {'age_weight': 2.8, 'mlp_hidden_layer_sizes': 65, 'mlp_alpha': 0.03920239877181633, 'mlp_learning_rate_init': 0.002995341445412559, 'lr_C': 0.03874530960894537}. Best is trial 45 with value: 0.7397265183903373.
# [I 2025-02-25 19:56:19,784] Trial 51 finished with value: 0.739741216333525 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 50, 'mlp_alpha': 0.0014576810033438828, 'mlp_learning_rate_init': 0.0022159993247805048, 'lr_C': 1.8003335920359251}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 19:58:06,569] Trial 52 finished with value: 0.7395569188788976 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 61, 'mlp_alpha': 0.0012630063345025928, 'mlp_learning_rate_init': 0.002314352054842854, 'lr_C': 2.77977710159492}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:00:10,220] Trial 53 finished with value: 0.7396673146326863 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 94, 'mlp_alpha': 0.0007312711303567858, 'mlp_learning_rate_init': 0.0028294691602649535, 'lr_C': 1.9393322076234047}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:01:27,459] Trial 54 finished with value: 0.7391368680166522 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 79, 'mlp_alpha': 0.0023743671718425155, 'mlp_learning_rate_init': 0.005062131515823109, 'lr_C': 12.264241004125466}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:03:54,186] Trial 55 finished with value: 0.7394693405671244 and parameters: {'age_weight': 2.2, 'mlp_hidden_layer_sizes': 63, 'mlp_alpha': 0.0008901461420955009, 'mlp_learning_rate_init': 0.0014205491449366876, 'lr_C': 0.3672720534028005}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:05:59,530] Trial 56 finished with value: 0.7396358412326888 and parameters: {'age_weight': 1.5, 'mlp_hidden_layer_sizes': 76, 'mlp_alpha': 0.006150714506018817, 'mlp_learning_rate_init': 0.001024673519697596, 'lr_C': 3.864727187284389}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:08:12,638] Trial 57 finished with value: 0.7395702015754525 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 101, 'mlp_alpha': 0.0013604579408633538, 'mlp_learning_rate_init': 0.002134630747752131, 'lr_C': 0.725625870687845}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:09:13,420] Trial 58 finished with value: 0.7381881606253554 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 93, 'mlp_alpha': 0.00012478665502340162, 'mlp_learning_rate_init': 0.0627779025411954, 'lr_C': 1.8142127154836976}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:10:29,222] Trial 59 finished with value: 0.7394331218791264 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 60, 'mlp_alpha': 0.017745204517741232, 'mlp_learning_rate_init': 0.0033186826850345997, 'lr_C': 11.178651879251682}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:11:47,304] Trial 60 finished with value: 0.7395506993851747 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 72, 'mlp_alpha': 0.002079593395391557, 'mlp_learning_rate_init': 0.004203311582301992, 'lr_C': 0.33715597701271577}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:13:32,040] Trial 61 finished with value: 0.7397173119705304 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 50, 'mlp_alpha': 0.003423844198549999, 'mlp_learning_rate_init': 0.0018663505704732248, 'lr_C': 1.1978312632481696}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:14:57,339] Trial 62 finished with value: 0.7395018969577803 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 52, 'mlp_alpha': 0.0032902729435785464, 'mlp_learning_rate_init': 0.002033352199081796, 'lr_C': 1.0601180132669632}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:16:35,357] Trial 63 finished with value: 0.73960530510715 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 64, 'mlp_alpha': 0.004039808464562355, 'mlp_learning_rate_init': 0.001643796367973215, 'lr_C': 3.101530945910286}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:17:54,942] Trial 64 finished with value: 0.7392640053882505 and parameters: {'age_weight': 2.2, 'mlp_hidden_layer_sizes': 50, 'mlp_alpha': 0.005370948043956006, 'mlp_learning_rate_init': 0.0028908837226600064, 'lr_C': 0.641065167836054}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:19:16,907] Trial 65 finished with value: 0.7393746420504378 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 83, 'mlp_alpha': 0.07535878673821818, 'mlp_learning_rate_init': 0.002542261956058234, 'lr_C': 0.20502189614910174}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:22:06,266] Trial 66 finished with value: 0.7394579347819367 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 69, 'mlp_alpha': 0.0010735212127811272, 'mlp_learning_rate_init': 0.0012628146605749677, 'lr_C': 5.4174421005522}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:23:43,205] Trial 67 finished with value: 0.7396072659016987 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 60, 'mlp_alpha': 0.002862484777361785, 'mlp_learning_rate_init': 0.0016179701983062738, 'lr_C': 1.8355140236848835}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:28:20,056] Trial 68 finished with value: 0.7395186677484201 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 261, 'mlp_alpha': 0.00029549891849279034, 'mlp_learning_rate_init': 0.002267339962492791, 'lr_C': 1.0714148948092048}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:29:52,804] Trial 69 finished with value: 0.7396536906686789 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 84, 'mlp_alpha': 0.007548009172632011, 'mlp_learning_rate_init': 0.0019897440905561675, 'lr_C': 0.4458012071295412}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:31:43,846] Trial 70 finished with value: 0.7396027107197982 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 73, 'mlp_alpha': 0.000643749391134732, 'mlp_learning_rate_init': 0.003203032294620101, 'lr_C': 1.6625151289105262}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:33:44,328] Trial 71 finished with value: 0.7395991818437343 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 58, 'mlp_alpha': 0.0018475236964794182, 'mlp_learning_rate_init': 0.0018122429683494346, 'lr_C': 1.4453644474964475}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:36:04,760] Trial 72 finished with value: 0.7395427032549445 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 50, 'mlp_alpha': 0.0004642971454751878, 'mlp_learning_rate_init': 0.0014634226259181017, 'lr_C': 3.700517646801557}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:38:05,173] Trial 73 finished with value: 0.7396404794167825 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 58, 'mlp_alpha': 0.0014869462244501501, 'mlp_learning_rate_init': 0.0018205828488892103, 'lr_C': 0.9108293065295003}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:40:08,895] Trial 74 finished with value: 0.7395837759939338 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 70, 'mlp_alpha': 0.0009341995785539611, 'mlp_learning_rate_init': 0.0027135949844697763, 'lr_C': 7.995598394161192}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:42:30,747] Trial 75 finished with value: 0.7396248388879431 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 50, 'mlp_alpha': 0.002333586472563008, 'mlp_learning_rate_init': 0.001108851580783111, 'lr_C': 2.3939515403979774}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:43:51,633] Trial 76 finished with value: 0.7393477365619011 and parameters: {'age_weight': 2.2, 'mlp_hidden_layer_sizes': 81, 'mlp_alpha': 0.004454607005298489, 'mlp_learning_rate_init': 0.0037914711192873064, 'lr_C': 0.2577257038534856}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:45:22,623] Trial 77 finished with value: 0.739552107644632 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 88, 'mlp_alpha': 0.012218814926962671, 'mlp_learning_rate_init': 0.002252008706017878, 'lr_C': 0.6536782248240869}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:47:53,558] Trial 78 finished with value: 0.7395546192078516 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 96, 'mlp_alpha': 0.0018855948496185003, 'mlp_learning_rate_init': 0.0016020687819373897, 'lr_C': 1.2818012307571907}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:49:08,827] Trial 79 finished with value: 0.7388219592982397 and parameters: {'age_weight': 1.4, 'mlp_hidden_layer_sizes': 105, 'mlp_alpha': 0.0998084895268388, 'mlp_learning_rate_init': 0.007714887217281395, 'lr_C': 4.408679239260984}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:49:58,855] Trial 80 finished with value: 0.7386604505864618 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 66, 'mlp_alpha': 0.002598893774623368, 'mlp_learning_rate_init': 0.02385307161232733, 'lr_C': 0.10752493573465254}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:51:55,730] Trial 81 finished with value: 0.7396912666421515 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 76, 'mlp_alpha': 0.0032691205701730415, 'mlp_learning_rate_init': 0.0019248518350413824, 'lr_C': 0.8102880945348985}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:53:40,287] Trial 82 finished with value: 0.7395096386239034 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 58, 'mlp_alpha': 0.0030190290171879055, 'mlp_learning_rate_init': 0.0019543213396072913, 'lr_C': 0.7945395364419897}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:55:48,275] Trial 83 finished with value: 0.7396164559544743 and parameters: {'age_weight': 2.3, 'mlp_hidden_layer_sizes': 74, 'mlp_alpha': 0.003348443434570242, 'mlp_learning_rate_init': 0.0013171887009226365, 'lr_C': 0.5447517497989293}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 20:58:15,743] Trial 84 finished with value: 0.7395193727701749 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 89, 'mlp_alpha': 0.0001815382928659162, 'mlp_learning_rate_init': 0.002580372308997599, 'lr_C': 2.6943542208758537}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:00:07,301] Trial 85 finished with value: 0.7395527650255774 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 79, 'mlp_alpha': 0.004951233804463794, 'mlp_learning_rate_init': 0.0017225080845017964, 'lr_C': 1.4760199838100365}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:01:54,176] Trial 86 finished with value: 0.7395644860851928 and parameters: {'age_weight': 2.2, 'mlp_hidden_layer_sizes': 66, 'mlp_alpha': 0.003985933148128285, 'mlp_learning_rate_init': 0.0022043444183338606, 'lr_C': 0.36780671295826667}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:03:45,386] Trial 87 finished with value: 0.7396195081631034 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 125, 'mlp_alpha': 0.0015148017717167375, 'mlp_learning_rate_init': 0.003157771377567941, 'lr_C': 2.07831136923893}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:09:10,533] Trial 88 finished with value: 0.7393801061023165 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 212, 'mlp_alpha': 0.0011459077237473735, 'mlp_learning_rate_init': 0.0011808295860366185, 'lr_C': 1.126169583841607}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:11:26,309] Trial 89 finished with value: 0.739561652922056 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 56, 'mlp_alpha': 0.0019347684769131467, 'mlp_learning_rate_init': 0.0014671120295672304, 'lr_C': 3.1032658837957823}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:12:56,996] Trial 90 finished with value: 0.7391057620992768 and parameters: {'age_weight': 2.3, 'mlp_hidden_layer_sizes': 112, 'mlp_alpha': 0.03858261872359967, 'mlp_learning_rate_init': 0.003490596710436836, 'lr_C': 6.022553112106963}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:14:57,839] Trial 91 finished with value: 0.7397226458875403 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 71, 'mlp_alpha': 0.0024965697481149985, 'mlp_learning_rate_init': 0.0019451992918247342, 'lr_C': 1.0083912275818154}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:16:57,088] Trial 92 finished with value: 0.7396977659616599 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 70, 'mlp_alpha': 0.00251600381223945, 'mlp_learning_rate_init': 0.0024017962898304837, 'lr_C': 0.8490111345279342}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:18:37,151] Trial 93 finished with value: 0.7395322129189866 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 78, 'mlp_alpha': 0.0026135247478380687, 'mlp_learning_rate_init': 0.0026564893929759445, 'lr_C': 0.8267181483501378}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:20:20,049] Trial 94 finished with value: 0.7397403792022876 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 71, 'mlp_alpha': 0.003403345623762333, 'mlp_learning_rate_init': 0.0023007643469784515, 'lr_C': 0.5651513063720135}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:21:55,229] Trial 95 finished with value: 0.7395768645322313 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 98, 'mlp_alpha': 0.006265358050775168, 'mlp_learning_rate_init': 0.002321674560041452, 'lr_C': 0.569600895720822}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:24:56,565] Trial 96 finished with value: 0.7397104234244334 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 300, 'mlp_alpha': 0.003609798745819622, 'mlp_learning_rate_init': 0.00206765931886224, 'lr_C': 0.42892815967699893}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:27:57,956] Trial 97 finished with value: 0.7396888891356511 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 179, 'mlp_alpha': 0.002096679239606073, 'mlp_learning_rate_init': 0.0020684668571259355, 'lr_C': 0.24520499980927146}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:30:59,185] Trial 98 finished with value: 0.739545798304277 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 241, 'mlp_alpha': 0.0013454273650075036, 'mlp_learning_rate_init': 0.0024658494750135576, 'lr_C': 0.43988872624663305}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:33:25,987] Trial 99 finished with value: 0.7394549571880006 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 299, 'mlp_alpha': 0.0037859515506616106, 'mlp_learning_rate_init': 0.003009040749151327, 'lr_C': 0.3196263699050322}. Best is trial 51 with value: 0.739741216333525.
# [I 2025-02-25 21:35:59,346] Trial 100 finished with value: 0.7397728716880495 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 272, 'mlp_alpha': 0.00845317970867336, 'mlp_learning_rate_init': 0.0016571269103940736, 'lr_C': 0.46212962978382793}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 21:38:49,131] Trial 101 finished with value: 0.7396964389702471 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 279, 'mlp_alpha': 0.008526880968857611, 'mlp_learning_rate_init': 0.001693860093094163, 'lr_C': 0.20100136830536672}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 21:41:02,183] Trial 102 finished with value: 0.7395361653110076 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 280, 'mlp_alpha': 0.014166968085372137, 'mlp_learning_rate_init': 0.0016714387454977897, 'lr_C': 0.2147062617365617}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 21:43:59,444] Trial 103 finished with value: 0.7394420319729439 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 289, 'mlp_alpha': 0.020613733984672318, 'mlp_learning_rate_init': 0.0014299512052270127, 'lr_C': 0.15256989736562684}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 21:46:58,287] Trial 104 finished with value: 0.7396400431057447 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 272, 'mlp_alpha': 0.008274321392661052, 'mlp_learning_rate_init': 0.0017597230653646394, 'lr_C': 0.4668890509034514}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 21:48:13,483] Trial 105 finished with value: 0.7392362605534739 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 286, 'mlp_alpha': 0.010046339594958388, 'mlp_learning_rate_init': 0.0994387596914061, 'lr_C': 0.13020790867602391}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 21:50:38,338] Trial 106 finished with value: 0.7394280583350291 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 265, 'mlp_alpha': 0.005553361656641169, 'mlp_learning_rate_init': 0.0021335168592471515, 'lr_C': 0.3689147745969395}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 21:53:08,020] Trial 107 finished with value: 0.7397208905388005 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 193, 'mlp_alpha': 0.006807340798946937, 'mlp_learning_rate_init': 0.0015347304434751448, 'lr_C': 1.0892042335136083}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 21:56:04,861] Trial 108 finished with value: 0.7397136578362989 and parameters: {'age_weight': 1.5, 'mlp_hidden_layer_sizes': 188, 'mlp_alpha': 0.0067166102479639025, 'mlp_learning_rate_init': 0.0013337274180159986, 'lr_C': 1.0707968224767794}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 21:59:04,120] Trial 109 finished with value: 0.7394940514650541 and parameters: {'age_weight': 1.4, 'mlp_hidden_layer_sizes': 195, 'mlp_alpha': 0.007035927852656863, 'mlp_learning_rate_init': 0.0011420745896000336, 'lr_C': 1.0336937639012966}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:01:19,923] Trial 110 finished with value: 0.7396071669131644 and parameters: {'age_weight': 1.5, 'mlp_hidden_layer_sizes': 148, 'mlp_alpha': 0.004762002453693348, 'mlp_learning_rate_init': 0.001381012886086421, 'lr_C': 1.6952224375803298}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:03:30,619] Trial 111 finished with value: 0.7394233303144354 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 254, 'mlp_alpha': 0.010722923269975157, 'mlp_learning_rate_init': 0.0023872674104766017, 'lr_C': 0.6410733460347336}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:04:47,572] Trial 112 finished with value: 0.7384483148694336 and parameters: {'age_weight': 1.5, 'mlp_hidden_layer_sizes': 214, 'mlp_alpha': 0.004253154513267847, 'mlp_learning_rate_init': 0.03504192451014705, 'lr_C': 1.309658132768664}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:07:30,192] Trial 113 finished with value: 0.7395999703891087 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 164, 'mlp_alpha': 0.006187566233489457, 'mlp_learning_rate_init': 0.0012613626513957967, 'lr_C': 0.527157420047667}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:10:24,842] Trial 114 finished with value: 0.7397196856688112 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 188, 'mlp_alpha': 0.0029101500750333066, 'mlp_learning_rate_init': 0.0014910760123915158, 'lr_C': 0.9535986659801113}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:13:34,043] Trial 115 finished with value: 0.7395048419311268 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 193, 'mlp_alpha': 0.002908122123946449, 'mlp_learning_rate_init': 0.001537708627211977, 'lr_C': 1.143984544600049}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:17:26,850] Trial 116 finished with value: 0.7395447098699292 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 173, 'mlp_alpha': 0.003485560810425875, 'mlp_learning_rate_init': 0.001009568450991327, 'lr_C': 1.697568130333265}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:19:48,376] Trial 117 finished with value: 0.7397023044554007 and parameters: {'age_weight': 1.5, 'mlp_hidden_layer_sizes': 187, 'mlp_alpha': 0.005228381398040378, 'mlp_learning_rate_init': 0.001983892733644902, 'lr_C': 2.267830744697193}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:24:23,574] Trial 118 finished with value: 0.739494250011265 and parameters: {'age_weight': 1.3, 'mlp_hidden_layer_sizes': 219, 'mlp_alpha': 0.001615403617721302, 'mlp_learning_rate_init': 0.0015248642019044425, 'lr_C': 0.9693274998038244}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:26:19,939] Trial 119 finished with value: 0.7395722103999439 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 204, 'mlp_alpha': 0.015968782804748755, 'mlp_learning_rate_init': 0.0018305037496486453, 'lr_C': 0.004503022182250639}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:29:21,620] Trial 120 finished with value: 0.7394522236316918 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 168, 'mlp_alpha': 0.0021583730558337837, 'mlp_learning_rate_init': 0.0015689012238799468, 'lr_C': 0.6481329130472253}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:31:46,251] Trial 121 finished with value: 0.7396671618338496 and parameters: {'age_weight': 1.4, 'mlp_hidden_layer_sizes': 186, 'mlp_alpha': 0.005146558995454633, 'mlp_learning_rate_init': 0.0020267078056582866, 'lr_C': 2.2741075410985823}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:34:15,306] Trial 122 finished with value: 0.7396779144527988 and parameters: {'age_weight': 1.5, 'mlp_hidden_layer_sizes': 184, 'mlp_alpha': 0.004195105511634253, 'mlp_learning_rate_init': 0.0013585926788216508, 'lr_C': 1.2889029767654943}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:35:59,013] Trial 123 finished with value: 0.7396105640735223 and parameters: {'age_weight': 1.5, 'mlp_hidden_layer_sizes': 194, 'mlp_alpha': 0.0073077718433845, 'mlp_learning_rate_init': 0.0027958479777171657, 'lr_C': 3.0134453691591663}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:38:24,016] Trial 124 finished with value: 0.7396557206859843 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 199, 'mlp_alpha': 0.0035459469699630976, 'mlp_learning_rate_init': 0.0019133641510583848, 'lr_C': 2.088593521334556}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:39:47,642] Trial 125 finished with value: 0.7387421124680933 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 183, 'mlp_alpha': 0.002973840328994864, 'mlp_learning_rate_init': 0.013111370022077233, 'lr_C': 0.4151708854730502}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:42:00,723] Trial 126 finished with value: 0.7396762540943204 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 175, 'mlp_alpha': 0.006002502000836073, 'mlp_learning_rate_init': 0.0021384093384410594, 'lr_C': 0.2944679842116366}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:44:46,871] Trial 127 finished with value: 0.7397440966604286 and parameters: {'age_weight': 1.5, 'mlp_hidden_layer_sizes': 199, 'mlp_alpha': 0.012538602039842483, 'mlp_learning_rate_init': 0.0012495151719786673, 'lr_C': 1.5372096627191085}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:47:02,547] Trial 128 finished with value: 0.7396162860364335 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 134, 'mlp_alpha': 0.01258128677240246, 'mlp_learning_rate_init': 0.001134677031808368, 'lr_C': 0.7212000347999745}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:49:07,001] Trial 129 finished with value: 0.7396881538331735 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 210, 'mlp_alpha': 0.027425821083742627, 'mlp_learning_rate_init': 0.001357348359846333, 'lr_C': 1.455899816179413}. Best is trial 100 with value: 0.7397728716880495.
# [I 2025-02-25 22:51:21,877] Trial 130 finished with value: 0.739799307487165 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 228, 'mlp_alpha': 0.01555429056802234, 'mlp_learning_rate_init': 0.0012525913268130527, 'lr_C': 0.9615465201887797}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 22:53:51,915] Trial 131 finished with value: 0.7396223983593564 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 224, 'mlp_alpha': 0.015654867611875848, 'mlp_learning_rate_init': 0.0010755902215420045, 'lr_C': 0.9681548791929313}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 22:56:17,944] Trial 132 finished with value: 0.7394523751302363 and parameters: {'age_weight': 1.9, 'mlp_hidden_layer_sizes': 241, 'mlp_alpha': 0.020482424235095793, 'mlp_learning_rate_init': 0.0012848308412004052, 'lr_C': 0.5607561599532455}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 22:59:14,402] Trial 133 finished with value: 0.7396730511907608 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 300, 'mlp_alpha': 0.009422624511162478, 'mlp_learning_rate_init': 0.0011948693333311469, 'lr_C': 1.0742159307794417}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:01:12,627] Trial 134 finished with value: 0.7393707521883665 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 255, 'mlp_alpha': 0.023599620811593603, 'mlp_learning_rate_init': 0.0016671735080998863, 'lr_C': 0.7848013720398512}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:03:19,814] Trial 135 finished with value: 0.7395876279068228 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 233, 'mlp_alpha': 0.011111095000840152, 'mlp_learning_rate_init': 0.0014945754725626346, 'lr_C': 1.717521780412117}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:05:08,832] Trial 136 finished with value: 0.739544780586998 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 191, 'mlp_alpha': 0.01742140653206655, 'mlp_learning_rate_init': 0.0017912674764506442, 'lr_C': 1.2671853307633048}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:07:09,175] Trial 137 finished with value: 0.7396600581230831 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 291, 'mlp_alpha': 0.014280786584740668, 'mlp_learning_rate_init': 0.0022568531073551058, 'lr_C': 3.495595486167842}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:08:57,887] Trial 138 finished with value: 0.739684630143616 and parameters: {'age_weight': 2.1, 'mlp_hidden_layer_sizes': 203, 'mlp_alpha': 0.031224862418604754, 'mlp_learning_rate_init': 0.0012427496333931318, 'lr_C': 0.5862065704157495}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:10:56,125] Trial 139 finished with value: 0.7394499275104605 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 229, 'mlp_alpha': 0.011715109731864928, 'mlp_learning_rate_init': 0.0015736209201071467, 'lr_C': 0.8946217706866021}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:12:33,567] Trial 140 finished with value: 0.7392071116958538 and parameters: {'age_weight': 2.0, 'mlp_hidden_layer_sizes': 180, 'mlp_alpha': 0.008085683661286105, 'mlp_learning_rate_init': 0.0026947645163401413, 'lr_C': 0.4376413432255633}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:14:24,568] Trial 141 finished with value: 0.7396641014488986 and parameters: {'age_weight': 1.5, 'mlp_hidden_layer_sizes': 189, 'mlp_alpha': 0.009372452619585067, 'mlp_learning_rate_init': 0.0019221462014014372, 'lr_C': 2.4376774174106806}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:16:13,283] Trial 142 finished with value: 0.7396133435706576 and parameters: {'age_weight': 1.5, 'mlp_hidden_layer_sizes': 199, 'mlp_alpha': 0.005008720212091657, 'mlp_learning_rate_init': 0.0020861624233209962, 'lr_C': 2.1657230312961833}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:18:50,505] Trial 143 finished with value: 0.7396148334118662 and parameters: {'age_weight': 1.4, 'mlp_hidden_layer_sizes': 163, 'mlp_alpha': 0.0024871499812575597, 'mlp_learning_rate_init': 0.0017430193675826615, 'lr_C': 4.890120507643552}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:21:26,220] Trial 144 finished with value: 0.7397498180517464 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 247, 'mlp_alpha': 0.006884079542146473, 'mlp_learning_rate_init': 0.0014339867981065675, 'lr_C': 1.5938181675585805}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:24:08,189] Trial 145 finished with value: 0.7396268703675258 and parameters: {'age_weight': 1.8, 'mlp_hidden_layer_sizes': 248, 'mlp_alpha': 0.006512682574936968, 'mlp_learning_rate_init': 0.0014077964757754702, 'lr_C': 1.604111444982864}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:26:55,023] Trial 146 finished with value: 0.7393118993034838 and parameters: {'age_weight': 3.0, 'mlp_hidden_layer_sizes': 272, 'mlp_alpha': 0.01436465470084011, 'mlp_learning_rate_init': 0.0010015895152482477, 'lr_C': 1.18553535695676}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:30:22,385] Trial 147 finished with value: 0.7396149492313192 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 266, 'mlp_alpha': 0.00311704347168769, 'mlp_learning_rate_init': 0.0016048462757784496, 'lr_C': 0.7347179382383141}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:32:25,630] Trial 148 finished with value: 0.7394360758751578 and parameters: {'age_weight': 1.7000000000000002, 'mlp_hidden_layer_sizes': 62, 'mlp_alpha': 0.0018199609692529308, 'mlp_learning_rate_init': 0.0014331091414633325, 'lr_C': 0.9071309363101121}. Best is trial 130 with value: 0.739799307487165.
# [I 2025-02-25 23:36:35,416] Trial 149 finished with value: 0.7395071160952954 and parameters: {'age_weight': 1.6, 'mlp_hidden_layer_sizes': 217, 'mlp_alpha': 0.0021632775413837233, 'mlp_learning_rate_init': 0.0012184102616323053, 'lr_C': 1.7885845113487755}. Best is trial 130 with value: 0.739799307487165.

# %%
# 최적의 하이퍼파라미터로 최종 모델 구성 및 평가
best_params = study.best_trial.params
age_weight = best_params["age_weight"]
mlp_params = {
    'hidden_layer_sizes' : best_params["mlp_hidden_layer_sizes"],
    'alpha' : best_params["mlp_alpha"],
    'learning_rate_init' : best_params["mlp_learning_rate_init"],
    'max_iter': 1000,
    'random_state': 42
}
X_train_weighted = X_train_encoded.copy()
if '시술 당시 나이' in X_train_encoded.columns:
    X_train_weighted['시술 당시 나이'] *= age_weight

# MLP 모델 정의
mlp_model = MLPClassifier(**mlp_params)

# 사전에 저장된 LightGBM 모델 불러오기 (변경 없음)
pre_trained_lgb = joblib.load('./LightGBM_boosting2.pkl')


# 베이스 모델 정의
base_models = [
    ('lgbm', pre_trained_lgb),
    ('mlp', mlp_model)
]

# 최적화된 메타 모델 (로지스틱 회귀)
best_meta = LogisticRegression(C=best_params['lr_C'], random_state=42, max_iter=1000)
# 스태킹 모델 구성
stacking_clf = StackingClassifier(estimators=base_models, final_estimator=best_meta, cv=StratifiedKFold(n_splits=3))

# %%
# 최종 모델 학습 및 평가
stacking_clf.fit(X_train_encoded, y)
# Out:
#   File "c:\Users\vhehr\.conda\envs\LGAimers6\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "c:\Users\vhehr\.conda\envs\LGAimers6\Lib\subprocess.py", line 556, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\vhehr\.conda\envs\LGAimers6\Lib\subprocess.py", line 1038, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\vhehr\.conda\envs\LGAimers6\Lib\subprocess.py", line 1550, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 66228, number of negative: 190123
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012872 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 716
# [LightGBM] [Info] Number of data points in the train set: 256351, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258349 -> initscore=-1.054568
# [LightGBM] [Info] Start training from score -1.054568
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 44152, number of negative: 126748
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006217 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 708
# [LightGBM] [Info] Number of data points in the train set: 170900, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258350 -> initscore=-1.054563
# [LightGBM] [Info] Start training from score -1.054563
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 44152, number of negative: 126749
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008864 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 710
# [LightGBM] [Info] Number of data points in the train set: 170901, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054571
# [LightGBM] [Info] Start training from score -1.054571
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 44152, number of negative: 126749
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007615 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 711
# [LightGBM] [Info] Number of data points in the train set: 170901, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054571
# [LightGBM] [Info] Start training from score -1.054571
# StackingClassifier(cv=StratifiedKFold(n_splits=3,
#         random_state=RandomState(MT19937) at 0x2722571C940, shuffle=False),
#                    estimators=[('lgbm',
#                                 LGBMClassifier(colsample_bytree=0.6283518615400887,
#                                                learning_rate=0.020414102740183366,
#                                                max_depth=9,
#                                                min_child_samples=14,
#                                                n_estimators=1020, num_leaves=35,
#                                                reg_alpha=9.422816220857865,
#                                                reg_lambda=3.965116334727029e-05,
#                                                subsample=0.8361505791254964)),
#                                ('mlp',
#                                 MLPClassifier(alpha=0.01555429056802234,
#                                               hidden_layer_sizes=228,
#                                               learning_rate_init=0.0012525913268130527,
#                                               max_iter=1000,
#                                               random_state=42))],
#                    final_estimator=LogisticRegression(C=0.9615465201887797,
#                                                       max_iter=1000,
#                                                       random_state=42))

# %%
import joblib
# 저장된 모델 불러오기
final_stack_model = joblib.load('./stacking(LightGBM+xgboost)_optimization2.pkl')

# 추가 학습을 위해 warm_start 활성화
final_stack_model.warm_start = True

# 추가 학습 진행 (적절한 X_train, y_train 데이터를 사용)
final_stack_model.fit(X_train_encoded, y)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 66228, number of negative: 190123
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011182 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 716
# [LightGBM] [Info] Number of data points in the train set: 256351, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258349 -> initscore=-1.054568
# [LightGBM] [Info] Start training from score -1.054568
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007628 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 715
# [LightGBM] [Info] Number of data points in the train set: 205080, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008235 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 716
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011736 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 712
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006705 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 715
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010830 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 715
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# StackingClassifier(cv=5,
#                    estimators=[('lgb',
#                                 LGBMClassifier(colsample_bytree=0.6283518615400887,
#                                                learning_rate=0.020414102740183366,
#                                                max_depth=9,
#                                                min_child_samples=14,
#                                                n_estimators=1020, num_leaves=35,
#                                                reg_alpha=9.422816220857865,
#                                                reg_lambda=3.965116334727029e-05,
#                                                subsample=0.8361505791254964)),
#                                ('xgb',
#                                 XGBClassifier(age_weight=3.0,
#                                               alpha=3.316179855488319,
#                                               base...
#                                               lambda=6.7896761098625875,
#                                               learning_rate=0.027493613405553185,
#                                               lr_C=0.22145350297974217,
#                                               max_bin=None,
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None, max_depth=8,
#                                               max_leaves=None,
#                                               min_child_weight=10, missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None, ...))],
#                    final_estimator=LogisticRegression(C=0.22145350297974217,
#                                                       max_iter=1000,
#                                                       random_state=42))

# %%
from sklearn.metrics import accuracy_score, roc_auc_score

# 예측
y_train_pred = stacking_clf.predict(X_train_encoded)
y_train_proba = stacking_clf.predict_proba(X_train_encoded)[:, 1]  # ROC-AUC Score 계산용

# 평가
accuracy = accuracy_score(y, y_train_pred)
roc_auc = roc_auc_score(y, y_train_proba)

# 출력
print(f"Accuracy: {accuracy:.4f}")
print(f"ROC-AUC Score: {roc_auc:.4f}")
# Out:
# Accuracy: 0.7486
# ROC-AUC Score: 0.7482

# %%
import joblib

# Optuna 최적화 실행 후 최적의 study 저장
joblib.dump(stacking_clf, "stacking(LightGBM+MLP)_optimization2.pkl")
# Out:
# ['stacking(LightGBM+MLP)_optimization2.pkl']

# %% [markdown]
# ### Predict

# %%
pred_proba = stacking_clf.predict_proba(X_test_encoded)[:, 1]

# %% [markdown]
# ### Submission

# %%
sample_submission = pd.read_csv('./Data/sample_submission.csv')
sample_submission['probability'] = pred_proba

# %%
sample_submission.to_csv('./stacking(LightGBM+MLP)_optimization_submit2.csv', index=False)
